# %%
import numpy as np
import pandas as pd
import requests
import json

# %%
def signature_extractor(file):
    
    # preprocessing data before 
            #calculating up/down regulated genes
        
    stat = pd.read_table(file, sep=" ")
    stat = stat.apply(pd.to_numeric)
    
    up_genes = []
    down_genes = []
    names = stat.columns
    
    # calculating up/down regulated genes
    
    if names[0] == "logFC" and names[2] == "PValue":
        up_genes = stat[(stat["logFC"] >= np.log(2)) & (stat["PValue"] <= 1e-3)].index
        down_genes = stat[(stat["logFC"] <= np.log(0.5)) & (stat["PValue"] <= 1e-3)].index
        
    if names[1] == "log2FoldChange" and names[5] == "padj":
        up_genes = stat[(stat["log2FoldChange"] >= np.log2(2)) & (stat["padj"] <= 1e-3)].index
        down_genes = stat[(stat["log2FoldChange"] <= np.log2(0.5)) & (stat["padj"] <= 1e-3)].index    
        
    return up_genes, down_genes

# %%
stat_edger = pd.read_table("~/Downloads/DE_heart_fb_deseq2_edger.txt", sep=" ")
stat_deseq = pd.read_table("~/Downloads/DE_heart_fb_deseq2_deseq2.txt", sep=" ")

# %%
stat_edger
# Out:
#                  logFC    logCPM         PValue
# A1BG         -1.698154  3.142090  8.742768e-153
# A1CF          0.789337 -1.235338   1.931845e-11
# A2M           4.161486  8.595770   0.000000e+00
# A2ML1        -0.843630  0.312166   9.159935e-25
# A2MP1         8.379818  0.348657   0.000000e+00
# ...                ...       ...            ...
# BP-2171C21.4  0.905227 -6.219698   1.194889e-01
# BP-2171C21.5  4.622840 -4.020418   4.622842e-52
# BP-2171C21.6  3.737071 -2.167515   2.873120e-95
# BP-2189O9.2   2.743989  2.278862   0.000000e+00
# YR211F11.2    3.688000 -6.498950   1.065551e-05
#
# [35238 rows x 3 columns]

# %%
stat_deseq
# Out:
#                  baseMean  log2FoldChange     lfcSE       stat         pvalue  \
# A1BG           104.033051       -1.290317  0.150884  -8.551720   1.212678e-17
# A1CF             5.198336        0.883494  0.128005   6.902011   5.127130e-12
# A2M           1073.552347        2.176929  0.221235   9.839893   7.579178e-23
# A2ML1           10.459817        0.689752  0.131503   5.245165   1.561428e-07
# A2MP1           17.444379        4.063652  0.152135  26.710848  3.521566e-157
# ...                   ...             ...       ...        ...            ...
# BP-2171C21.4     1.320363       -0.409913  0.127170  -3.223338   1.267059e-03
# BP-2171C21.5     1.764268        0.774370  0.134721   5.747972   9.032043e-09
# BP-2171C21.6     4.207419        1.430520  0.130206  10.986614   4.432452e-28
# BP-2189O9.2     39.811244        4.247406  0.168005  25.281404  5.116107e-141
# YR211F11.2       1.231159       -0.346113  0.126787  -2.729885   6.335634e-03
#
#                        padj
# A1BG           9.294413e-17
# A1CF           2.735763e-11
# A2M            7.591673e-22
# A2ML1          5.384772e-07
# A2MP1         4.206541e-155
# ...                     ...
# BP-2171C21.4   1.990488e-03
# BP-2171C21.5   3.586154e-08
# BP-2171C21.6   5.491939e-27
# BP-2189O9.2   4.794718e-139
# YR211F11.2     9.138187e-03
#
# [35238 rows x 6 columns]

# %%
up_genes_edger, down_genes_edger = signature_extractor("~/Downloads/DE_heart_fb_deseq2_edger.txt")

# %%
up_genes_deseq, down_genes_deseq = signature_extractor("~/Downloads/DE_heart_fb_deseq2_deseq2.txt")

# %%
pd.DataFrame(up_genes_edger)
# Out:
#                  0
# 0             A1CF
# 1              A2M
# 2            A2MP1
# 3          A3GALT2
# 4           A4GALT
# ...            ...
# 8575  BP-2171C21.2
# 8576  BP-2171C21.5
# 8577  BP-2171C21.6
# 8578   BP-2189O9.2
# 8579    YR211F11.2
#
# [8580 rows x 1 columns]

# %%
url = 'https://maayanlab.cloud/L1000CDS2/query'

def upperGenes(genes):
    # The app uses uppercase gene symbols. So it is crucial to perform upperGenes() step.
    return [gene.upper() for gene in genes]

# gene-set search example
data = {"upGenes":up_genes_edger,
"dnGenes":down_genes_edger}
data['upGenes'] = upperGenes(data['upGenes'])
data['dnGenes'] = upperGenes(data['dnGenes'])
config = {"aggravate":True,"searchMethod":"geneSet","share":True,"combination":True,"db-version":"latest"}
metadata = [{"key":"Tag","value":"gene-set python example"},{"key":"Cell","value":"MCF7"}]
payload = {"data":data,"config":config,"meta":metadata}
headers = {'content-type':'application/json'}
r = requests.post(url,data=json.dumps(payload),headers=headers)
resGeneSet = r.json()

# %%
resGeneSet["topMeta"]
# Out:
# [{'pert_desc': 'PP-110',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K03618428',
#   'cell_id': 'HT29',
#   'pert_dose': '22.2',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC006_HT29_24H:BRD-K03618428:22.2',
#   'score': 0.0324,
#   'overlap': {'up/up': ['ADH1C',
#     'ALDH5A1',
#     'ALDH6A1',
#     'BTG2',
#     'C11ORF71',
#     'C1QA',
#     'CALCOCO1',
#     'CFTR',
#     'CLCA1',
#     'CLIC5',
#     'DECR1',
#     'EFNA1',
#     'ERBB4',
#     'F13A1',
#     'FCGBP',
#     'FOXO4',
#     'GLTSCR2',
#     'HPGD',
#     'KLHL24',
#     'KRT20',
#     'LEFTY1',
#     'MAOA',
#     'MUC2',
#     'PCK1',
#     'PDZD2',
#     'RAP1GAP',
#     'SEPP1',
#     'SESN1',
#     'ST6GAL1',
#     'ST6GALNAC2',
#     'TNNT1',
#     'TSC22D3',
#     'TST',
#     'VSIG4',
#     'WT1',
#     'ZNF91'],
#    'dn/dn': ['ABCE1',
#     'ACSL3',
#     'ADK',
#     'AGPAT5',
#     'ALDH1A3',
#     'ANP32E',
#     'APOBEC3B',
#     'ARNTL2',
#     'ASCC3',
#     'ASF1B',
#     'ASPM',
#     'ATF5',
#     'AURKA',
#     'AURKB',
#     'BAG2',
#     'BARD1',
#     'BCLAF1',
#     'BIRC5',
#     'BRCA1',
#     'BUB1',
#     'CACYBP',
#     'CBFB',
#     'CCNA2',
#     'CCNF',
#     'CD3EAP',
#     'CDC123',
#     'CDC20',
#     'CDC25A',
#     'CDC45',
#     'CDC6',
#     'CDC7',
#     'CDCA3',
#     'CDCA4',
#     'CDCA8',
#     'CDK1',
#     'CDKN3',
#     'CDT1',
#     'CENPA',
#     'CENPE',
#     'CENPF',
#     'CENPM',
#     'CENPN',
#     'CEP55',
#     'CHAF1A',
#     'CHEK2',
#     'CIT',
#     'CKS1B',
#     'CKS2',
#     'COPS3',
#     'COTL1',
#     'CSE1L',
#     'CSRP2',
#     'CXCL1',
#     'CYP1B1',
#     'DBF4',
#     'DDB2',
#     'DDX10',
#     'DDX21',
#     'DDX39A',
#     'DEPDC1',
#     'DHFR',
#     'DKC1',
#     'DKK1',
#     'DLEU1',
#     'DLGAP5',
#     'DNAJC9',
#     'DONSON',
#     'DSCC1',
#     'DTL',
#     'DUSP6',
#     'EBP',
#     'ECT2',
#     'EED',
#     'EIF4E',
#     'EIF4EBP1',
#     'ELOVL6',
#     'ENO1',
#     'ERCC6L',
#     'ESPL1',
#     'EXO1',
#     'EXOSC2',
#     'EXOSC9',
#     'EZH2',
#     'FAM57A',
#     'FANCA',
#     'FANCI',
#     'FASN',
#     'FBXO5',
#     'FEN1',
#     'FOSL1',
#     'FOXM1',
#     'GAL',
#     'GCLM',
#     'GINS1',
#     'GINS2',
#     'GPRC5A',
#     'GTPBP4',
#     'GTSE1',
#     'H2AFX',
#     'HAT1',
#     'HJURP',
#     'HMGA1',
#     'HMGB2',
#     'HMMR',
#     'HN1',
#     'HPRT1',
#     'HSPA14',
#     'HSPA4L',
#     'HSPD1',
#     'HSPE1',
#     'IARS',
#     'IDI1',
#     'IER3',
#     'KIAA0101',
#     'KIF11',
#     'KIF14',
#     'KIF15',
#     'KIF18B',
#     'KIF20A',
#     'KIF20B',
#     'KIF23',
#     'KIF2C',
#     'KIF4A',
#     'KPNA2',
#     'LBR',
#     'LIG1',
#     'LMNB1',
#     'LMNB2',
#     'LOXL1',
#     'LRP8',
#     'LRRC59',
#     'LSM3',
#     'LSM6',
#     'MAD2L1',
#     'MAK16',
#     'MCM10',
#     'MCM2',
#     'MCM4',
#     'MCM5',
#     'MCM6',
#     'MCM7',
#     'ME1',
#     'MELK',
#     'MKI67',
#     'MRPL42',
#     'MTHFD2',
#     'MYBL2',
#     'MYC',
#     'NAA15',
#     'NCAPD3',
#     'NCAPG',
#     'NCAPG2',
#     'NCAPH',
#     'NCBP1',
#     'NDC80',
#     'NEIL3',
#     'NEK2',
#     'NME1',
#     'NOC3L',
#     'NOLC1',
#     'NOP16',
#     'NUDT1',
#     'NUP155',
#     'NUP205',
#     'NUP88',
#     'NUP93',
#     'NUSAP1',
#     'ODC1',
#     'OIP5',
#     'ORC6',
#     'PA2G4',
#     'PAICS',
#     'PARP2',
#     'PAX5',
#     'PBK',
#     'PCNA',
#     'PEX3',
#     'PGD',
#     'PHLDA1',
#     'PHLDA2',
#     'PKMYT1',
#     'PLAC8',
#     'PLK1',
#     'PLK4',
#     'PNO1',
#     'PNP',
#     'POLA2',
#     'POLE2',
#     'POLE3',
#     'POLQ',
#     'POLR3K',
#     'PPAT',
#     'PRC1',
#     'PRIM1',
#     'PRPF4',
#     'PRPS1',
#     'PSMD12',
#     'PSMD14',
#     'PSME3',
#     'PTGES',
#     'PTGS2',
#     'PTTG1',
#     'PUS7',
#     'PYCR1',
#     'RACGAP1',
#     'RAD23B',
#     'RAD51',
#     'RAD54L',
#     'RAN',
#     'RANBP1',
#     'RCC1',
#     'RFC2',
#     'RFC3',
#     'RFC4',
#     'RFC5',
#     'RGS4',
#     'RPA3',
#     'RRM1',
#     'RRM2',
#     'RRP15',
#     'SACS',
#     'SERPINE2',
#     'SHCBP1',
#     'SKP2',
#     'SLC16A3',
#     'SLC17A9',
#     'SLC19A1',
#     'SLC25A15',
#     'SLC35F2',
#     'SLC5A6',
#     'SLC7A1',
#     'SLIRP',
#     'SMAGP',
#     'SMC2',
#     'SMC4',
#     'SNRPD1',
#     'SNRPF',
#     'SPAG5',
#     'SPATS2L',
#     'SPC25',
#     'SRM',
#     'SRP72',
#     'SRPRB',
#     'SRSF3',
#     'SRSF7',
#     'STEAP1',
#     'SYNCRIP',
#     'TACC3',
#     'TACSTD2',
#     'TDP1',
#     'TEX10',
#     'TFRC',
#     'TIMELESS',
#     'TIPIN',
#     'TK1',
#     'TMPO',
#     'TNC',
#     'TOP2A',
#     'TPX2',
#     'TRA2B',
#     'TRIM16',
#     'TRIP13',
#     'TROAP',
#     'TSR1',
#     'TTK',
#     'TUBG1',
#     'TYMS',
#     'UBE2C',
#     'UBE2N',
#     'UBE2S',
#     'UCHL1',
#     'UCHL3',
#     'USP1',
#     'USP14',
#     'VRK1',
#     'WDR12',
#     'YRDC',
#     'ZWILCH',
#     'ZWINT']},
#   'DEGcount': 486,
#   'pubchem_id': '24905203'},
#  {'pert_desc': 'PLX-4032',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K56343971',
#   'cell_id': 'A375',
#   'pert_dose': '10.0',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC006_A375_24H:BRD-K56343971:10.0',
#   'score': 0.0275,
#   'overlap': {'up/up': ['A2M',
#     'ABLIM1',
#     'ALDH6A1',
#     'APOD',
#     'AQP1',
#     'BTG2',
#     'CA2',
#     'CAP2',
#     'CD52',
#     'CES2',
#     'CFD',
#     'CKB',
#     'CLCA4',
#     'CNN1',
#     'COL21A1',
#     'CPA3',
#     'CRYAB',
#     'DES',
#     'DNAJB2',
#     'DUSP22',
#     'EPHX1',
#     'ERBB2',
#     'F11R',
#     'FAM63A',
#     'FCGBP',
#     'FHL1',
#     'GATA6',
#     'GRB7',
#     'GSN',
#     'IRF6',
#     'ISYNA1',
#     'KCNMB1',
#     'LDB3',
#     'LPAR6',
#     'MMP28',
#     'MTSS1',
#     'NCAM1',
#     'OBSL1',
#     'OGN',
#     'OLFML2A',
#     'PCP4',
#     'PDE4DIP',
#     'PDZRN3',
#     'PEG3',
#     'PGAP3',
#     'PIK3C2B',
#     'PIK3R1',
#     'PNRC1',
#     'PPP1R16B',
#     'SAMSN1',
#     'SCGB1D2',
#     'SLC27A6',
#     'SLC6A8',
#     'SPP1',
#     'SSPN',
#     'ST6GALNAC2',
#     'STK38L',
#     'TF',
#     'UQCRB'],
#    'dn/dn': ['ACOT7',
#     'ALDH1A3',
#     'ANP32E',
#     'APOBEC3B',
#     'ARL6IP1',
#     'ASF1B',
#     'ASPM',
#     'AURKA',
#     'AURKB',
#     'BASP1',
#     'BAZ1A',
#     'BCLAF1',
#     'BIRC5',
#     'BRCA1',
#     'BUB1',
#     'BUB3',
#     'BZW1',
#     'CALD1',
#     'CASP7',
#     'CBFB',
#     'CCNA2',
#     'CCND1',
#     'CCNF',
#     'CD24',
#     'CD3EAP',
#     'CDC123',
#     'CDC25A',
#     'CDC45',
#     'CDC6',
#     'CDCA3',
#     'CDCA4',
#     'CDCA8',
#     'CDK1',
#     'CDKN3',
#     'CENPA',
#     'CENPE',
#     'CENPF',
#     'CENPN',
#     'CEP55',
#     'CHAF1A',
#     'CHAF1B',
#     'CHEK2',
#     'CHST11',
#     'CIT',
#     'CKAP5',
#     'CKS1B',
#     'CKS2',
#     'CSE1L',
#     'CST1',
#     'CXCL1',
#     'DBF4',
#     'DCK',
#     'DEPDC1',
#     'DKK1',
#     'DLGAP5',
#     'DNAJA1',
#     'DNAJC9',
#     'DTL',
#     'DUSP4',
#     'DUSP6',
#     'ECT2',
#     'EIF4A3',
#     'EIF4E',
#     'ENC1',
#     'ENO1',
#     'ESPL1',
#     'ETV4',
#     'EXO1',
#     'EXOSC9',
#     'EZH2',
#     'FAM111A',
#     'FAM64A',
#     'FANCI',
#     'FBXO5',
#     'FEN1',
#     'FJX1',
#     'FOSL1',
#     'FOXM1',
#     'GABPB1',
#     'GAL',
#     'GALNT14',
#     'GINS1',
#     'GINS2',
#     'GPRC5A',
#     'GTPBP4',
#     'GTSE1',
#     'H2AFX',
#     'H2AFZ',
#     'HJURP',
#     'HLTF',
#     'HMGA2',
#     'HMGB1',
#     'HMGB2',
#     'HMMR',
#     'HN1',
#     'HNRNPD',
#     'HOXC6',
#     'HPRT1',
#     'HSP90AA1',
#     'HSPA14',
#     'HSPA8',
#     'HSPE1',
#     'HSPH1',
#     'IDI1',
#     'IER3',
#     'IGFBP3',
#     'ITGB5',
#     'KIAA0101',
#     'KIF11',
#     'KIF14',
#     'KIF15',
#     'KIF18B',
#     'KIF20A',
#     'KIF20B',
#     'KIF23',
#     'KIF2C',
#     'KIF4A',
#     'KPNA2',
#     'KRT18',
#     'KRT7',
#     'LEF1',
#     'LIF',
#     'LIG1',
#     'LMNB2',
#     'LRP8',
#     'MAD2L1',
#     'MAFF',
#     'MAK16',
#     'MALT1',
#     'MCM10',
#     'MCM4',
#     'MCM5',
#     'MCM7',
#     'MELK',
#     'MICB',
#     'MIS18A',
#     'MKI67',
#     'MYBL2',
#     'NCAPG',
#     'NCAPG2',
#     'NCAPH',
#     'NEIL3',
#     'NEK2',
#     'NET1',
#     'NOLC1',
#     'NPY',
#     'NR2F2',
#     'NUDT1',
#     'NUP62',
#     'NUSAP1',
#     'ORC6',
#     'OSBPL3',
#     'PAICS',
#     'PARP2',
#     'PBK',
#     'PCNA',
#     'PHLDA1',
#     'PHLDA2',
#     'PKMYT1',
#     'PLAUR',
#     'PLK1',
#     'PLK4',
#     'PNP',
#     'POLA2',
#     'POLE2',
#     'POLR3G',
#     'POLR3K',
#     'PPAT',
#     'PRC1',
#     'PRDX1',
#     'PRPS1',
#     'PTTG1',
#     'RACGAP1',
#     'RAD51',
#     'RFC2',
#     'RFC3',
#     'RFWD3',
#     'RGS4',
#     'RNASEH2A',
#     'RPA3',
#     'RPS11',
#     'RRM1',
#     'RRM2',
#     'RUNX3',
#     'S100A11',
#     'S100A2',
#     'SACS',
#     'SCML1',
#     'SHCBP1',
#     'SKA1',
#     'SKP2',
#     'SLC16A3',
#     'SLC19A1',
#     'SLC20A1',
#     'SLC25A15',
#     'SMC2',
#     'SMC4',
#     'SMS',
#     'SNRPB',
#     'SNRPD1',
#     'SNRPF',
#     'SPAG5',
#     'SPATS2L',
#     'SPC25',
#     'SRSF10',
#     'SRSF3',
#     'SRSF7',
#     'STC1',
#     'STIL',
#     'STK17A',
#     'STMN1',
#     'TACC3',
#     'TDG',
#     'TDP1',
#     'TFAP2B',
#     'TIPIN',
#     'TK1',
#     'TMEM2',
#     'TMEM97',
#     'TMPO',
#     'TNFRSF12A',
#     'TOP1',
#     'TOP2A',
#     'TPX2',
#     'TRA2B',
#     'TRIP13',
#     'TSPAN8',
#     'TTK',
#     'TUBB',
#     'TUBB3',
#     'TUBG1',
#     'TXN',
#     'TYMS',
#     'UAP1',
#     'UBE2C',
#     'UBE2N',
#     'UBE2S',
#     'UCK2',
#     'UGCG',
#     'USP1',
#     'VRK1',
#     'YRDC',
#     'ZWINT']},
#   'DEGcount': 517,
#   'pubchem_id': '42611257'},
#  {'pert_desc': 'PP-110',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K03618428',
#   'cell_id': 'A375',
#   'pert_dose': '22.2',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC006_A375_24H:BRD-K03618428:22.2',
#   'score': 0.0261,
#   'overlap': {'up/up': ['A2M',
#     'ABLIM1',
#     'ALDH6A1',
#     'ANK2',
#     'APOD',
#     'ARHGEF9',
#     'BCAM',
#     'BTG2',
#     'C14ORF159',
#     'CAP2',
#     'CLCA4',
#     'DMPK',
#     'DUSP22',
#     'FCGBP',
#     'FOXO4',
#     'GATA6',
#     'GSN',
#     'HIST2H2BE',
#     'KAT2B',
#     'MMP28',
#     'MTSS1',
#     'OBSL1',
#     'PDZRN3',
#     'PEG3',
#     'PGAP3',
#     'PTGER4',
#     'SCGB1D2',
#     'SEPP1',
#     'SLC27A6',
#     'SLC6A8',
#     'SSPN',
#     'ST6GALNAC2',
#     'STK38L',
#     'TM7SF2',
#     'TPSB2'],
#    'dn/dn': ['ABCE1',
#     'ACOT7',
#     'ACTN1',
#     'ANP32E',
#     'ANXA2P2',
#     'APOBEC3B',
#     'ARL6IP1',
#     'ASF1B',
#     'ASPM',
#     'AURKA',
#     'AURKB',
#     'AXL',
#     'BCLAF1',
#     'BIRC5',
#     'BRCA1',
#     'BUB1',
#     'BUB3',
#     'BZW1',
#     'CACYBP',
#     'CALD1',
#     'CBFB',
#     'CBX3',
#     'CCNA2',
#     'CCNB2',
#     'CCND1',
#     'CCNE2',
#     'CCNF',
#     'CD24',
#     'CDC123',
#     'CDC25A',
#     'CDC42',
#     'CDC45',
#     'CDC6',
#     'CDCA3',
#     'CDCA4',
#     'CDCA8',
#     'CDK1',
#     'CDKN3',
#     'CDR2',
#     'CENPA',
#     'CENPE',
#     'CENPF',
#     'CENPN',
#     'CEP55',
#     'CHAF1A',
#     'CHAF1B',
#     'CHEK2',
#     'CIT',
#     'CKS1B',
#     'CKS2',
#     'CSE1L',
#     'CXCL1',
#     'DBF4',
#     'DCK',
#     'DDX39A',
#     'DEPDC1',
#     'DKK1',
#     'DLGAP5',
#     'DNAJC9',
#     'DNMT3B',
#     'DTL',
#     'DUSP6',
#     'EBP',
#     'EIF4A3',
#     'EIF4E',
#     'EIF4EBP1',
#     'ENO1',
#     'ESPL1',
#     'EXO1',
#     'EXOSC9',
#     'EZH2',
#     'FAM111A',
#     'FAM64A',
#     'FANCI',
#     'FBXO5',
#     'FEN1',
#     'FOSL1',
#     'FOXM1',
#     'FSCN1',
#     'FXYD5',
#     'GABPB1',
#     'GCLM',
#     'GINS1',
#     'GINS2',
#     'GPRC5A',
#     'GTSE1',
#     'H2AFX',
#     'H2AFZ',
#     'HAT1',
#     'HJURP',
#     'HLTF',
#     'HMGA2',
#     'HMGB1',
#     'HMGB2',
#     'HMMR',
#     'HN1',
#     'HN1L',
#     'HOXC10',
#     'HOXC6',
#     'HPRT1',
#     'HSP90AA1',
#     'HSPA14',
#     'HSPA8',
#     'HSPE1',
#     'HSPH1',
#     'IER3',
#     'IGFBP3',
#     'INHBA',
#     'ITGB5',
#     'KIAA0101',
#     'KIF11',
#     'KIF14',
#     'KIF15',
#     'KIF18B',
#     'KIF20A',
#     'KIF20B',
#     'KIF23',
#     'KIF2C',
#     'KIF4A',
#     'KIFC1',
#     'KPNA2',
#     'KRT18',
#     'KRT7',
#     'LIG1',
#     'LMNB1',
#     'LMNB2',
#     'LRRC59',
#     'LSM3',
#     'MAD2L1',
#     'MCM10',
#     'MCM2',
#     'MCM4',
#     'MCM5',
#     'MCM6',
#     'MCM7',
#     'ME1',
#     'MICB',
#     'MIS18A',
#     'MKI67',
#     'MRPL42',
#     'MTHFD2',
#     'MYBL1',
#     'MYBL2',
#     'NCAPG',
#     'NCAPG2',
#     'NCAPH',
#     'NDC80',
#     'NEIL3',
#     'NEK2',
#     'NET1',
#     'NF2',
#     'NKX3-1',
#     'NME1',
#     'NOLC1',
#     'NPY',
#     'NUDT1',
#     'NUP188',
#     'NUP88',
#     'NUSAP1',
#     'OIP5',
#     'ORC6',
#     'OSBPL8',
#     'PAICS',
#     'PARP2',
#     'PBK',
#     'PCNA',
#     'PHLDA1',
#     'PHLDA2',
#     'PKMYT1',
#     'PLAUR',
#     'PLK1',
#     'PLK4',
#     'PNP',
#     'POLA2',
#     'POLE2',
#     'POLR3K',
#     'POMP',
#     'PPAT',
#     'PRC1',
#     'PRDX1',
#     'PRPS1',
#     'PSMC3IP',
#     'PSMD14',
#     'PTGES',
#     'PTTG1',
#     'PTX3',
#     'RACGAP1',
#     'RAD51',
#     'RFC2',
#     'RFC3',
#     'RFWD3',
#     'RGS2',
#     'RNASEH2A',
#     'RPA3',
#     'RRM1',
#     'RRM2',
#     'S100A11',
#     'S100A2',
#     'SACS',
#     'SCML1',
#     'SERPINE2',
#     'SHCBP1',
#     'SKA1',
#     'SKP2',
#     'SLC19A1',
#     'SLC20A1',
#     'SLC25A15',
#     'SMAGP',
#     'SMC2',
#     'SMC4',
#     'SMURF2',
#     'SNRPA1',
#     'SNRPB',
#     'SNRPD1',
#     'SNRPD3',
#     'SNRPF',
#     'SNRPG',
#     'SPAG5',
#     'SPC25',
#     'SRSF10',
#     'SRSF3',
#     'SRSF6',
#     'SRSF7',
#     'STIL',
#     'STMN1',
#     'SYNCRIP',
#     'TACC3',
#     'TDP1',
#     'TIMELESS',
#     'TIPIN',
#     'TK1',
#     'TMEM97',
#     'TMPO',
#     'TNFRSF12A',
#     'TOP2A',
#     'TPX2',
#     'TRA2B',
#     'TRIP13',
#     'TROAP',
#     'TSPAN8',
#     'TTK',
#     'TUBB',
#     'TUBB6',
#     'TUBG1',
#     'TXN',
#     'TYMS',
#     'UAP1',
#     'UBE2C',
#     'UBE2N',
#     'UBE2S',
#     'UGCG',
#     'USP1',
#     'USP14',
#     'VRK1',
#     'WSB2',
#     'ZWILCH',
#     'ZWINT']},
#   'DEGcount': 509,
#   'pubchem_id': '24905203'},
#  {'pert_desc': 'BMS-536924',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K34581968',
#   'cell_id': 'HT29',
#   'pert_dose': '11.1',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC006_HT29_24H:BRD-K34581968:11.1',
#   'score': 0.026,
#   'overlap': {'up/up': ['APOD',
#     'AQP1',
#     'C10ORF10',
#     'CALCOCO1',
#     'CLIC5',
#     'DNAJB2',
#     'EFNA1',
#     'ERBB2',
#     'ERBB4',
#     'F11R',
#     'F13A1',
#     'FABP4',
#     'FAM63A',
#     'FOXO4',
#     'GAB2',
#     'GLTSCR2',
#     'GRB7',
#     'GSN',
#     'HIST2H2BE',
#     'HPGD',
#     'JUP',
#     'KDR',
#     'KLHL24',
#     'KRT20',
#     'MARCH2',
#     'MSLN',
#     'PCK1',
#     'PDZK1',
#     'RGS5',
#     'SLC6A8',
#     'ST6GAL1',
#     'SYNPO',
#     'TSC22D3',
#     'VEGFA',
#     'ZFPM2',
#     'ZNF91'],
#    'dn/dn': ['AASDHPPT',
#     'ABCE1',
#     'ADK',
#     'AGPAT5',
#     'ALDH1A3',
#     'ALG8',
#     'ANP32B',
#     'ANP32E',
#     'APOBEC3B',
#     'ASCC3',
#     'ASF1B',
#     'AURKA',
#     'AURKB',
#     'BAG2',
#     'BCLAF1',
#     'BIRC5',
#     'BRCA1',
#     'BUB1',
#     'C11ORF24',
#     'CCNA2',
#     'CCNE1',
#     'CCNF',
#     'CCT2',
#     'CD3EAP',
#     'CDC123',
#     'CDC25A',
#     'CDC45',
#     'CDC6',
#     'CDC7',
#     'CDCA3',
#     'CDCA4',
#     'CDK1',
#     'CDKN3',
#     'CENPA',
#     'CENPF',
#     'CENPN',
#     'CEP55',
#     'CHEK2',
#     'CIT',
#     'CKS2',
#     'COTL1',
#     'CSE1L',
#     'CSRP2',
#     'CXCL12',
#     'CYP1B1',
#     'DBF4',
#     'DDB2',
#     'DDX10',
#     'DDX21',
#     'DDX39A',
#     'DEPDC1',
#     'DIMT1',
#     'DKC1',
#     'DKK1',
#     'DLEU1',
#     'DLGAP5',
#     'DNAJC9',
#     'DONSON',
#     'DSCC1',
#     'DTL',
#     'EBNA1BP2',
#     'EBP',
#     'EED',
#     'EIF4A3',
#     'EIF4E',
#     'EIF4EBP1',
#     'ENO1',
#     'ESPL1',
#     'EXO1',
#     'EXOSC2',
#     'EXOSC4',
#     'EXOSC9',
#     'EZH2',
#     'FAM57A',
#     'FANCI',
#     'FASN',
#     'FEN1',
#     'FKBP11',
#     'FOSL1',
#     'GAL',
#     'GCLM',
#     'GGCT',
#     'GINS1',
#     'GINS2',
#     'GNL3',
#     'GTPBP4',
#     'GTSE1',
#     'H2AFX',
#     'HAT1',
#     'HES1',
#     'HJURP',
#     'HMMR',
#     'HN1',
#     'HNRNPD',
#     'HPRT1',
#     'HSPA14',
#     'HSPA4L',
#     'HSPD1',
#     'HSPE1',
#     'IARS',
#     'IL13RA2',
#     'KIAA0101',
#     'KIF14',
#     'KIF15',
#     'KIF18B',
#     'KIF20A',
#     'KIF2C',
#     'KIF4A',
#     'KPNA2',
#     'LBR',
#     'LIG1',
#     'LMNB1',
#     'LOXL1',
#     'LRP8',
#     'LSM6',
#     'MAD2L1',
#     'MAK16',
#     'MCM10',
#     'MCM2',
#     'MCM4',
#     'MCM5',
#     'MCM6',
#     'MCM7',
#     'ME1',
#     'MELK',
#     'MINA',
#     'MIS18A',
#     'MKI67',
#     'MRPL3',
#     'MRPL42',
#     'MRTO4',
#     'MYBL2',
#     'MYC',
#     'MYCBP',
#     'NAA15',
#     'NCAPD3',
#     'NCAPG',
#     'NCAPG2',
#     'NCAPH',
#     'NCBP1',
#     'NEIL3',
#     'NME1',
#     'NOC3L',
#     'NOLC1',
#     'NOP16',
#     'NPM3',
#     'NPY',
#     'NUP155',
#     'NUP188',
#     'NUP205',
#     'NUP93',
#     'ODC1',
#     'ORC5',
#     'ORC6',
#     'PA2G4',
#     'PAICS',
#     'PARP2',
#     'PBK',
#     'PFN2',
#     'PHLDA1',
#     'PLK1',
#     'PLK4',
#     'PMS1',
#     'PNP',
#     'POLA2',
#     'POLE2',
#     'POLR3G',
#     'POLR3K',
#     'PPAT',
#     'PPIH',
#     'PRC1',
#     'PRIM1',
#     'PRPS1',
#     'PRR7',
#     'PSME3',
#     'PUS7',
#     'RACGAP1',
#     'RAD51',
#     'RAN',
#     'RFC2',
#     'RFC3',
#     'RFC4',
#     'RFC5',
#     'RGS2',
#     'RGS4',
#     'RPP40',
#     'RRM1',
#     'RRM2',
#     'RRP15',
#     'RUVBL1',
#     'SACS',
#     'SERPINE2',
#     'SHCBP1',
#     'SKP2',
#     'SLC25A15',
#     'SLC5A6',
#     'SLIRP',
#     'SMC2',
#     'SMC4',
#     'SNRPD1',
#     'SNRPF',
#     'SPAG5',
#     'SPC25',
#     'SRM',
#     'SRPRB',
#     'SRSF3',
#     'SRSF7',
#     'STEAP1',
#     'STRA13',
#     'SUPT16H',
#     'SYNCRIP',
#     'TACC3',
#     'TCERG1',
#     'TDP1',
#     'TEX10',
#     'TFRC',
#     'TIPIN',
#     'TK1',
#     'TMEM97',
#     'TMPO',
#     'TMX2',
#     'TNC',
#     'TNFRSF10B',
#     'TOP2A',
#     'TPX2',
#     'TRA2B',
#     'TRIP13',
#     'TSR1',
#     'TTK',
#     'TUBG1',
#     'TYMS',
#     'UBE2C',
#     'UBE2N',
#     'UBE2S',
#     'USP1',
#     'VRK1',
#     'WDR12',
#     'YRDC',
#     'ZWILCH',
#     'ZWINT']},
#   'DEGcount': 465,
#   'pubchem_id': '11353973'},
#  {'pert_desc': 'BMS-536924',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K34581968',
#   'cell_id': 'A375',
#   'pert_dose': '11.1',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC006_A375_24H:BRD-K34581968:11.1',
#   'score': 0.0259,
#   'overlap': {'up/up': ['A2M',
#     'ALDH6A1',
#     'ALOX5AP',
#     'APOD',
#     'AQP1',
#     'BTG2',
#     'CD74',
#     'CDKN1B',
#     'CES2',
#     'CPA3',
#     'DMPK',
#     'EFNA1',
#     'EPHX1',
#     'ERBB2',
#     'FABP4',
#     'FCGBP',
#     'FOXO4',
#     'FXYD3',
#     'GATA6',
#     'GSN',
#     'HIST2H2BE',
#     'KAT2B',
#     'LPAR6',
#     'MMP28',
#     'MTSS1',
#     'OBSL1',
#     'PAM',
#     'PDE4DIP',
#     'PGAP3',
#     'PNRC1',
#     'PROM1',
#     'PTGER4',
#     'RPS6KA2',
#     'S100A8',
#     'SCGB1D2',
#     'SLC27A3',
#     'SLC6A8',
#     'SSPN',
#     'ST6GALNAC2',
#     'TM7SF2',
#     'TPSAB1',
#     'TPSB2',
#     'TXNIP'],
#    'dn/dn': ['ABCE1',
#     'ACOT7',
#     'ANP32E',
#     'ANXA1',
#     'APOBEC3B',
#     'ASF1B',
#     'ASPM',
#     'AURKA',
#     'AURKB',
#     'BATF3',
#     'BAZ1A',
#     'BIRC5',
#     'BRCA1',
#     'BUB1',
#     'BUB3',
#     'BZW1',
#     'CALD1',
#     'CASP7',
#     'CBFB',
#     'CBX3',
#     'CCDC86',
#     'CCNA2',
#     'CCND1',
#     'CCNE2',
#     'CCNF',
#     'CCT5',
#     'CD3EAP',
#     'CDC25A',
#     'CDC25B',
#     'CDC45',
#     'CDC6',
#     'CDCA3',
#     'CDCA4',
#     'CDCA8',
#     'CDK1',
#     'CDKN3',
#     'CENPA',
#     'CENPF',
#     'CENPN',
#     'CEP55',
#     'CHAF1A',
#     'CHAF1B',
#     'CIT',
#     'CKAP5',
#     'CKS1B',
#     'CKS2',
#     'COL6A1',
#     'CSE1L',
#     'CST1',
#     'CXCL1',
#     'DBF4',
#     'DCK',
#     'DDX21',
#     'DDX39A',
#     'DEPDC1',
#     'DKC1',
#     'DKK1',
#     'DLGAP5',
#     'DNAJC9',
#     'DNMT3B',
#     'DSCC1',
#     'DTL',
#     'EBP',
#     'ECT2',
#     'EIF1AX',
#     'EIF4A3',
#     'EIF4E',
#     'EIF4EBP1',
#     'ENO1',
#     'ESPL1',
#     'EXO1',
#     'EXOSC9',
#     'EZH2',
#     'FAM111A',
#     'FAM64A',
#     'FANCI',
#     'FBXO5',
#     'FEN1',
#     'FKBP11',
#     'FOSL1',
#     'FOXM1',
#     'FXYD5',
#     'GABPB1',
#     'GAL',
#     'GCH1',
#     'GINS1',
#     'GINS2',
#     'GNL3',
#     'GPRC5A',
#     'GTPBP4',
#     'GTSE1',
#     'H2AFX',
#     'H2AFZ',
#     'HAT1',
#     'HJURP',
#     'HLTF',
#     'HMGA2',
#     'HMGB1',
#     'HMGB2',
#     'HMMR',
#     'HN1',
#     'HNRNPAB',
#     'HNRNPD',
#     'HOXC6',
#     'HPRT1',
#     'HSP90AA1',
#     'HSPA14',
#     'HSPA8',
#     'HSPD1',
#     'HSPH1',
#     'IER3',
#     'IGFBP3',
#     'IL7R',
#     'INHBA',
#     'KIAA0101',
#     'KIF11',
#     'KIF14',
#     'KIF15',
#     'KIF18B',
#     'KIF20A',
#     'KIF23',
#     'KIF2C',
#     'KIF4A',
#     'KPNA2',
#     'KRT18',
#     'KRT7',
#     'LEF1',
#     'LIG1',
#     'LMNB2',
#     'MAD2L1',
#     'MAK16',
#     'MCM10',
#     'MCM2',
#     'MCM4',
#     'MCM5',
#     'MCM6',
#     'MCM7',
#     'MELK',
#     'MIS18A',
#     'MKI67',
#     'MRPL3',
#     'MTHFD2',
#     'MYBL1',
#     'MYBL2',
#     'NAA15',
#     'NAMPT',
#     'NAV3',
#     'NCAPD3',
#     'NCAPG',
#     'NCAPG2',
#     'NCAPH',
#     'NEIL3',
#     'NEK2',
#     'NME1',
#     'NOLC1',
#     'NOP16',
#     'NPM1',
#     'NPY',
#     'NUDT1',
#     'NUP155',
#     'NUSAP1',
#     'ORC6',
#     'PAICS',
#     'PARP2',
#     'PBK',
#     'PDGFA',
#     'PHLDA1',
#     'PHLDA2',
#     'PI3',
#     'PKMYT1',
#     'PLAUR',
#     'PLK1',
#     'PLK4',
#     'PLS3',
#     'PNP',
#     'POLA2',
#     'POLE2',
#     'POLR3G',
#     'POLR3K',
#     'PPAT',
#     'PRC1',
#     'PRDX1',
#     'PRIM1',
#     'PRPS1',
#     'PSMD14',
#     'PTTG1',
#     'PTX3',
#     'PYCR1',
#     'RACGAP1',
#     'RAD51',
#     'RFC2',
#     'RFC3',
#     'RFC4',
#     'RFWD3',
#     'RNASEH2A',
#     'RPA3',
#     'RPP30',
#     'RPS11',
#     'RRM1',
#     'RRM2',
#     'SACS',
#     'SCML1',
#     'SHCBP1',
#     'SKA1',
#     'SKP2',
#     'SLC19A1',
#     'SLC20A1',
#     'SLC25A15',
#     'SLC7A1',
#     'SMC2',
#     'SMC4',
#     'SNRPA1',
#     'SNRPB',
#     'SNRPD1',
#     'SPAG5',
#     'SPC25',
#     'SRPRB',
#     'SRSF3',
#     'SRSF7',
#     'STIL',
#     'STMN1',
#     'SYNCRIP',
#     'TACC3',
#     'TDP1',
#     'TFAM',
#     'TIMELESS',
#     'TIPIN',
#     'TK1',
#     'TMEM97',
#     'TMPO',
#     'TNFRSF12A',
#     'TOP2A',
#     'TPM4',
#     'TPX2',
#     'TRA2B',
#     'TRIP13',
#     'TSPAN8',
#     'TTK',
#     'TUBB',
#     'TUBB6',
#     'TUBG1',
#     'TXN',
#     'TYMS',
#     'UAP1',
#     'UBE2C',
#     'UBE2S',
#     'UCK2',
#     'UGCG',
#     'VRK1',
#     'XRCC5',
#     'YRDC',
#     'ZWILCH',
#     'ZWINT']},
#   'DEGcount': 506,
#   'pubchem_id': '11353973'},
#  {'pert_desc': 'AS605240',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K41895714',
#   'cell_id': 'A375',
#   'pert_dose': '10.0',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC006_A375_24H:BRD-K41895714:10.0',
#   'score': 0.0258,
#   'overlap': {'up/up': ['ABLIM1',
#     'AGT',
#     'ALOX5AP',
#     'ANXA9',
#     'APOD',
#     'AQP1',
#     'ATHL1',
#     'ATP1B1',
#     'BTG2',
#     'C1QB',
#     'C3',
#     'CAP2',
#     'CD14',
#     'CD163',
#     'CFD',
#     'CKB',
#     'CNN1',
#     'CRYAB',
#     'DES',
#     'DMPK',
#     'DNAJB2',
#     'DUSP22',
#     'EFNA1',
#     'EPHA3',
#     'EPHX1',
#     'ERBB2',
#     'FAM107A',
#     'FAM63A',
#     'FCGBP',
#     'GATA6',
#     'GFAP',
#     'GLUL',
#     'GPX3',
#     'GSN',
#     'HPGDS',
#     'KAT2B',
#     'MTSS1',
#     'MYH11',
#     'MYL9',
#     'NOL3',
#     'OBSL1',
#     'PDZRN3',
#     'PGAP3',
#     'PIK3C2B',
#     'PLEKHB1',
#     'S100A8',
#     'SCGB1D2',
#     'SEPP1',
#     'SERPINA3',
#     'SLC6A8',
#     'ST6GALNAC2',
#     'TM7SF2',
#     'VSIG4',
#     'VTCN1',
#     'ZSCAN18'],
#    'dn/dn': ['ACOT7',
#     'ALDH1A3',
#     'ANP32E',
#     'APOBEC3B',
#     'ARHGAP29',
#     'ASF1B',
#     'ASPM',
#     'AURKA',
#     'AURKB',
#     'BAZ1A',
#     'BIRC5',
#     'BRCA1',
#     'BUB1',
#     'BUB3',
#     'BZW1',
#     'CBFB',
#     'CBX3',
#     'CCNA2',
#     'CCND1',
#     'CCNF',
#     'CD24',
#     'CD3EAP',
#     'CDC25A',
#     'CDC45',
#     'CDC6',
#     'CDCA3',
#     'CDCA4',
#     'CDCA8',
#     'CDK1',
#     'CDKN3',
#     'CENPA',
#     'CENPF',
#     'CENPN',
#     'CEP55',
#     'CHAF1A',
#     'CHAF1B',
#     'CHORDC1',
#     'CIT',
#     'CKS1B',
#     'CKS2',
#     'CPS1',
#     'CSE1L',
#     'CXCL1',
#     'DBF4',
#     'DDX21',
#     'DEPDC1',
#     'DHFR',
#     'DKC1',
#     'DKK1',
#     'DLC1',
#     'DLGAP5',
#     'DNAJC9',
#     'DSCC1',
#     'DTL',
#     'DUSP4',
#     'DUSP6',
#     'EBNA1BP2',
#     'ECT2',
#     'EIF4EBP1',
#     'EIF5A',
#     'ENC1',
#     'ENO1',
#     'ESPL1',
#     'ETV4',
#     'EXO1',
#     'EXOSC2',
#     'EXOSC9',
#     'FANCI',
#     'FASN',
#     'FBXO5',
#     'FEN1',
#     'FKBP11',
#     'FN1',
#     'FOSL1',
#     'G3BP1',
#     'GABPB1',
#     'GAL',
#     'GARS',
#     'GGCT',
#     'GINS2',
#     'GNL3',
#     'GPRC5A',
#     'GTPBP4',
#     'GTSE1',
#     'H2AFZ',
#     'HAT1',
#     'HELLS',
#     'HJURP',
#     'HMGA2',
#     'HMGB2',
#     'HMMR',
#     'HNRNPAB',
#     'HNRNPD',
#     'HOXC6',
#     'HSP90AA1',
#     'HSPA8',
#     'HSPD1',
#     'HSPE1',
#     'HSPH1',
#     'IER3',
#     'IGFBP3',
#     'IL7R',
#     'INHBA',
#     'ITGB5',
#     'KIF11',
#     'KIF14',
#     'KIF15',
#     'KIF18A',
#     'KIF18B',
#     'KIF20A',
#     'KIF23',
#     'KIF2C',
#     'KIF4A',
#     'KRT18',
#     'LEF1',
#     'LIG1',
#     'LMNB2',
#     'LRIF1',
#     'MAD2L1',
#     'MAFF',
#     'MAK16',
#     'MARCKS',
#     'MCM10',
#     'MCM2',
#     'MCM4',
#     'MCM5',
#     'MCM6',
#     'MCM7',
#     'MELK',
#     'MICB',
#     'MIS18A',
#     'MKI67',
#     'MME',
#     'MOK',
#     'MSH2',
#     'MTF2',
#     'MTHFD2',
#     'MYBL1',
#     'MYBL2',
#     'NCAPG',
#     'NCAPG2',
#     'NCAPH',
#     'NEIL3',
#     'NEK2',
#     'NET1',
#     'NFE2L3',
#     'NOLC1',
#     'NOP16',
#     'NUSAP1',
#     'ORC6',
#     'PAICS',
#     'PARP2',
#     'PBK',
#     'PHLDA1',
#     'PHLDA2',
#     'PKMYT1',
#     'PLAC8',
#     'PLAUR',
#     'PLK1',
#     'PLK4',
#     'PNP',
#     'POLA2',
#     'POLE2',
#     'POLQ',
#     'POLR3K',
#     'PPAT',
#     'PRC1',
#     'PRIM1',
#     'RACGAP1',
#     'RAD51',
#     'RAD51AP1',
#     'RAN',
#     'RFC2',
#     'RFC3',
#     'RFWD3',
#     'RGS4',
#     'RRM1',
#     'RRM2',
#     'RUNX3',
#     'RUVBL1',
#     'SACS',
#     'SCML1',
#     'SHCBP1',
#     'SLC19A1',
#     'SLC20A1',
#     'SMC2',
#     'SMC4',
#     'SPAG5',
#     'SPATS2L',
#     'SPC25',
#     'SRM',
#     'SRSF3',
#     'SRSF7',
#     'STC1',
#     'STIL',
#     'STMN1',
#     'STX1A',
#     'TACC3',
#     'TCP1',
#     'TDP1',
#     'TEX10',
#     'TFAM',
#     'TFDP1',
#     'TIPIN',
#     'TK1',
#     'TMEM2',
#     'TMEM97',
#     'TMPO',
#     'TOP2A',
#     'TPX2',
#     'TRA2B',
#     'TRIP13',
#     'TSPAN8',
#     'TTK',
#     'TYMS',
#     'UAP1',
#     'UBE2C',
#     'UBE2S',
#     'UCK2',
#     'UGCG',
#     'USP1',
#     'VRK1',
#     'ZWILCH',
#     'ZWINT']},
#   'DEGcount': 470,
#   'pubchem_id': '10377751'},
#  {'pert_desc': 'AS605240',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K41895714',
#   'cell_id': 'HT29',
#   'pert_dose': '10.0',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC006_HT29_24H:BRD-K41895714:10.0',
#   'score': 0.0247,
#   'overlap': {'up/up': ['ABAT',
#     'ADH1C',
#     'AQP1',
#     'BLNK',
#     'CALCOCO1',
#     'CES2',
#     'CLIC5',
#     'DECR1',
#     'DNAJB2',
#     'EFNA1',
#     'ERBB2',
#     'ERBB4',
#     'FAM63A',
#     'FOXO4',
#     'GLTSCR2',
#     'KLHL24',
#     'MAOA',
#     'MTSS1',
#     'PCK1',
#     'PDZK1',
#     'PRR15L',
#     'RARRES1',
#     'SEPP1',
#     'SESN1',
#     'SI',
#     'TSC22D3',
#     'TST',
#     'TTC39A',
#     'TXNIP',
#     'VTCN1',
#     'ZNF91'],
#    'dn/dn': ['ABCE1',
#     'AGPAT5',
#     'ANP32E',
#     'ASF1B',
#     'ASNS',
#     'ASPM',
#     'AURKA',
#     'AURKB',
#     'BCLAF1',
#     'BID',
#     'BIRC5',
#     'BRCA1',
#     'BUB1',
#     'BUB3',
#     'BYSL',
#     'CAD',
#     'CALU',
#     'CBFB',
#     'CCNA2',
#     'CCND1',
#     'CCNF',
#     'CDC123',
#     'CDC25A',
#     'CDC45',
#     'CDC6',
#     'CDCA3',
#     'CDCA4',
#     'CDK1',
#     'CDKN3',
#     'CENPA',
#     'CENPF',
#     'CENPN',
#     'CEP55',
#     'CHEK2',
#     'CHSY1',
#     'CIT',
#     'CKAP5',
#     'CKS2',
#     'CSE1L',
#     'CYR61',
#     'DBF4',
#     'DDX10',
#     'DDX18',
#     'DDX21',
#     'DDX39A',
#     'DIMT1',
#     'DKC1',
#     'DKK1',
#     'DLGAP5',
#     'DONSON',
#     'DSCC1',
#     'DTL',
#     'DUSP4',
#     'DUSP6',
#     'ECT2',
#     'EEF1E1',
#     'EIF4E',
#     'EIF4EBP1',
#     'ELOVL6',
#     'ENO1',
#     'EXO1',
#     'EXOSC9',
#     'FANCI',
#     'FASN',
#     'FBXO5',
#     'FEN1',
#     'FOSL1',
#     'GAL',
#     'GCH1',
#     'GINS1',
#     'GINS2',
#     'GTPBP4',
#     'GTSE1',
#     'H2AFX',
#     'HJURP',
#     'HMGB2',
#     'HN1',
#     'HNRNPAB',
#     'HPRT1',
#     'HSP90AB1',
#     'HSPA14',
#     'HSPA4L',
#     'HSPA8',
#     'HSPD1',
#     'IARS',
#     'IER3',
#     'IL13RA2',
#     'IMPDH2',
#     'IPO4',
#     'IPO5',
#     'IRAK1',
#     'ITGB5',
#     'KIAA0101',
#     'KIF11',
#     'KIF14',
#     'KIF18B',
#     'KIF20B',
#     'KIF23',
#     'KIF2C',
#     'KIF4A',
#     'KPNA2',
#     'KRT18',
#     'LMNB2',
#     'LOXL1',
#     'LRP8',
#     'LRRC59',
#     'LSM6',
#     'MAD2L1',
#     'MAK16',
#     'MAP7',
#     'MARCKS',
#     'MCM10',
#     'MCM2',
#     'MCM4',
#     'MCM6',
#     'MCM7',
#     'MELK',
#     'MIS18A',
#     'MKI67',
#     'MRPL42',
#     'MRTO4',
#     'MSH6',
#     'MTHFD2',
#     'MYBL2',
#     'MYC',
#     'NCAPD3',
#     'NCAPG',
#     'NCAPG2',
#     'NCAPH',
#     'NCL',
#     'NELL2',
#     'NME1',
#     'NOC3L',
#     'NOLC1',
#     'NOP16',
#     'NPM1',
#     'NPM3',
#     'NUP93',
#     'NUSAP1',
#     'ODC1',
#     'ORC6',
#     'PA2G4',
#     'PAICS',
#     'PARP2',
#     'PBK',
#     'PHGDH',
#     'PHLDA1',
#     'PHLDA2',
#     'PLK1',
#     'PLK4',
#     'PNO1',
#     'PNP',
#     'POLA2',
#     'POLR3G',
#     'POLR3K',
#     'PPAT',
#     'PRC1',
#     'PRNP',
#     'PRPS1',
#     'PTRF',
#     'PUS7',
#     'PYCR1',
#     'RAD51',
#     'RAN',
#     'RANBP1',
#     'RCC1',
#     'RFC2',
#     'RFC3',
#     'RFC5',
#     'RNASEH2A',
#     'RRM1',
#     'RRM2',
#     'RUVBL1',
#     'SACS',
#     'SEH1L',
#     'SFN',
#     'SHCBP1',
#     'SKP2',
#     'SLC19A1',
#     'SLC25A15',
#     'SLC25A32',
#     'SLC35F2',
#     'SLC5A6',
#     'SLC7A11',
#     'SMC2',
#     'SMC4',
#     'SNRPD1',
#     'SNRPF',
#     'SPC25',
#     'SRM',
#     'SSRP1',
#     'SUPT16H',
#     'SYNCRIP',
#     'TACC3',
#     'TACSTD2',
#     'TFRC',
#     'TIPIN',
#     'TMF1',
#     'TMPO',
#     'TMX2',
#     'TNFRSF10B',
#     'TOP2A',
#     'TPM4',
#     'TPX2',
#     'TRIP13',
#     'TSPAN4',
#     'TTK',
#     'TYMS',
#     'UBE2C',
#     'UBE2N',
#     'UBE2S',
#     'UCHL1',
#     'UCK2',
#     'VRK1',
#     'WDR12',
#     'WDR43',
#     'YRDC',
#     'ZWILCH']},
#   'DEGcount': 407,
#   'pubchem_id': '10377751'},
#  {'pert_desc': '-666',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K57080016',
#   'cell_id': 'A375',
#   'pert_dose': '80.0',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC006_A375_24H:BRD-K57080016:80.0',
#   'score': 0.0246,
#   'overlap': {'up/up': ['APOD',
#     'ATP1B1',
#     'BTG2',
#     'CD14',
#     'CES2',
#     'CFD',
#     'CNN1',
#     'CRIP1',
#     'CRIP2',
#     'CRYAB',
#     'DECR1',
#     'DES',
#     'DNAJB2',
#     'DUSP22',
#     'EFNA1',
#     'ERBB2',
#     'FCGBP',
#     'GATA6',
#     'GSN',
#     'LPAR6',
#     'MTSS1',
#     'OBSL1',
#     'OLFML2A',
#     'PCP4',
#     'PDZRN3',
#     'PEG3',
#     'PGAP3',
#     'PIK3R1',
#     'PNRC1',
#     'RRAD',
#     'SCGB1D2',
#     'SEPP1',
#     'SLC6A8',
#     'SOX10',
#     'ST6GALNAC2',
#     'TM7SF2',
#     'VSIG4',
#     'VTCN1'],
#    'dn/dn': ['ANP32E',
#     'APOBEC3B',
#     'ASAP1',
#     'ASF1B',
#     'ASPM',
#     'AURKA',
#     'AURKB',
#     'BASP1',
#     'BAZ1A',
#     'BIRC5',
#     'BRCA1',
#     'BUB1',
#     'CBFB',
#     'CCNA2',
#     'CCNB2',
#     'CCND1',
#     'CCNE2',
#     'CCNF',
#     'CD3EAP',
#     'CDC25A',
#     'CDC45',
#     'CDC6',
#     'CDC7',
#     'CDCA3',
#     'CDCA4',
#     'CDCA8',
#     'CDK1',
#     'CDK2',
#     'CDKN3',
#     'CDT1',
#     'CENPA',
#     'CENPF',
#     'CENPM',
#     'CENPN',
#     'CEP55',
#     'CHAF1A',
#     'CHORDC1',
#     'CIT',
#     'CKS1B',
#     'CKS2',
#     'CSE1L',
#     'CXCL1',
#     'DBF4',
#     'DCLRE1C',
#     'DDX21',
#     'DEPDC1',
#     'DHFR',
#     'DKC1',
#     'DKK1',
#     'DLGAP5',
#     'DNAJA1',
#     'DNAJC9',
#     'DNMBP',
#     'DSCC1',
#     'DTL',
#     'DUSP4',
#     'DUSP6',
#     'ECT2',
#     'EIF4E',
#     'EIF4EBP1',
#     'EIF5A',
#     'ENC1',
#     'ESPL1',
#     'ETV4',
#     'EXO1',
#     'EZH2',
#     'FAM64A',
#     'FANCI',
#     'FASN',
#     'FBXO5',
#     'FEN1',
#     'FJX1',
#     'FKBP11',
#     'FN1',
#     'FOSL1',
#     'FOXM1',
#     'GABPB1',
#     'GAL',
#     'GART',
#     'GINS2',
#     'GPRC5A',
#     'GTPBP4',
#     'GTSE1',
#     'H2AFX',
#     'H2AFZ',
#     'HAT1',
#     'HELLS',
#     'HJURP',
#     'HMGA1',
#     'HMGA2',
#     'HMGB2',
#     'HMMR',
#     'HNRNPAB',
#     'HSP90AA1',
#     'HSPA14',
#     'HSPA8',
#     'HSPD1',
#     'HSPH1',
#     'IER3',
#     'IGFBP3',
#     'INHBA',
#     'ITGB5',
#     'KIAA0101',
#     'KIF11',
#     'KIF14',
#     'KIF15',
#     'KIF18B',
#     'KIF20A',
#     'KIF20B',
#     'KIF23',
#     'KIF2C',
#     'KIF4A',
#     'KRT18',
#     'LEF1',
#     'LIG1',
#     'LMNB1',
#     'LMNB2',
#     'LRP8',
#     'MAD2L1',
#     'MAFF',
#     'MCM10',
#     'MCM2',
#     'MCM4',
#     'MCM5',
#     'MCM6',
#     'MCM7',
#     'MELK',
#     'MICB',
#     'MIS18A',
#     'MKI67',
#     'MOK',
#     'MSH2',
#     'MTHFD2',
#     'MYBL1',
#     'MYBL2',
#     'MYH10',
#     'NAA15',
#     'NAV3',
#     'NCAPD3',
#     'NCAPG',
#     'NCAPG2',
#     'NCAPH',
#     'NDC80',
#     'NEIL3',
#     'NEK2',
#     'NET1',
#     'NOLC1',
#     'NOP16',
#     'NPM1',
#     'NT5E',
#     'NUDT1',
#     'NUSAP1',
#     'ODC1',
#     'ORC6',
#     'OSBPL3',
#     'PAICS',
#     'PARP2',
#     'PBK',
#     'PHLDA1',
#     'PHLDA2',
#     'PKMYT1',
#     'PLAUR',
#     'PLK1',
#     'PLK4',
#     'PMAIP1',
#     'PNP',
#     'POLA2',
#     'POLE2',
#     'POLR3K',
#     'PPAT',
#     'PRC1',
#     'PRIM1',
#     'PSMD14',
#     'PTTG1',
#     'PYCR1',
#     'RACGAP1',
#     'RAD51',
#     'RCC1',
#     'RFC2',
#     'RFC3',
#     'RFWD3',
#     'RGS4',
#     'RPA2',
#     'RRM1',
#     'RRM2',
#     'RUNX3',
#     'RUVBL1',
#     'SCML1',
#     'SEH1L',
#     'SHCBP1',
#     'SKA1',
#     'SLC19A1',
#     'SLC20A1',
#     'SLC25A15',
#     'SMC2',
#     'SMC4',
#     'SMURF2',
#     'SPAG5',
#     'SPATS2L',
#     'SPC25',
#     'SRP72',
#     'SRSF7',
#     'STC1',
#     'STIL',
#     'STMN1',
#     'STX1A',
#     'TACC3',
#     'TDP1',
#     'TFPI2',
#     'TIMELESS',
#     'TK1',
#     'TMEM2',
#     'TMEM97',
#     'TMPO',
#     'TOP1',
#     'TOP2A',
#     'TPX2',
#     'TRA2B',
#     'TRIP13',
#     'TROAP',
#     'TTK',
#     'TUBG1',
#     'TYMS',
#     'UAP1',
#     'UBE2C',
#     'UBE2S',
#     'UCK2',
#     'UGCG',
#     'USP1',
#     'VRK1',
#     'WSB2',
#     'YRDC',
#     'ZWILCH',
#     'ZWINT']},
#   'DEGcount': 462,
#   'pubchem_id': '10127622'},
#  {'pert_desc': '-666',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K98490050',
#   'cell_id': 'MCF7',
#   'pert_dose': '10.0',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC015_MCF7_24H:BRD-K98490050:10.0',
#   'score': 0.0239,
#   'overlap': {'up/up': ['ABAT',
#     'AQP3',
#     'ATP1B1',
#     'BTG2',
#     'CST3',
#     'CYB5R1',
#     'DDC',
#     'GSN',
#     'HIST2H2BE',
#     'IGKV1-5',
#     'JAG1',
#     'KDM6B',
#     'MAOA',
#     'PHF1',
#     'PIK3C2B',
#     'PINK1',
#     'RAP1GAP',
#     'S100P',
#     'SESN1',
#     'SIK1',
#     'TACC2',
#     'TBC1D8',
#     'TSC22D3',
#     'TXNIP'],
#    'dn/dn': ['ANP32B',
#     'ANP32E',
#     'APOBEC3B',
#     'ARL6IP1',
#     'ASF1B',
#     'ASPM',
#     'AURKA',
#     'AURKB',
#     'BARD1',
#     'BIRC5',
#     'BORA',
#     'BRCA1',
#     'BUB1',
#     'C1ORF112',
#     'CA12',
#     'CCNA2',
#     'CCNB2',
#     'CCNE2',
#     'CCNF',
#     'CDC20',
#     'CDC25C',
#     'CDC45',
#     'CDC6',
#     'CDC7',
#     'CDCA3',
#     'CDCA8',
#     'CDK1',
#     'CDKN3',
#     'CDT1',
#     'CENPA',
#     'CENPE',
#     'CENPF',
#     'CENPM',
#     'CENPN',
#     'CEP55',
#     'CHAF1A',
#     'CHEK1',
#     'CHEK2',
#     'CHN1',
#     'CIT',
#     'CKAP5',
#     'CKS1B',
#     'CKS2',
#     'CSE1L',
#     'CSRP2',
#     'CXCL12',
#     'DBF4',
#     'DCK',
#     'DEK',
#     'DEPDC1',
#     'DHFR',
#     'DLEU1',
#     'DLGAP5',
#     'DNA2',
#     'DNAJC9',
#     'DNMT3B',
#     'DSCC1',
#     'DTL',
#     'DTYMK',
#     'DUT',
#     'ECT2',
#     'EFEMP1',
#     'EIF5A',
#     'ERCC6L',
#     'ESPL1',
#     'EXO1',
#     'EZH2',
#     'FAM64A',
#     'FANCA',
#     'FANCG',
#     'FANCI',
#     'FBXO5',
#     'FEN1',
#     'FOXM1',
#     'GABPB1',
#     'GEMIN2',
#     'GGCT',
#     'GGH',
#     'GINS1',
#     'GINS2',
#     'GINS4',
#     'GMNN',
#     'GPSM2',
#     'GTSE1',
#     'H2AFX',
#     'H2AFZ',
#     'HAT1',
#     'HELLS',
#     'HIST1H4C',
#     'HJURP',
#     'HMGB1',
#     'HMGB2',
#     'HMMR',
#     'HOXC6',
#     'HPRT1',
#     'ITGB3BP',
#     'KIAA0101',
#     'KIF11',
#     'KIF14',
#     'KIF15',
#     'KIF18A',
#     'KIF18B',
#     'KIF20A',
#     'KIF20B',
#     'KIF23',
#     'KIF2C',
#     'KIF4A',
#     'KIFC1',
#     'KNTC1',
#     'KPNA2',
#     'LMNB1',
#     'LMNB2',
#     'LSM5',
#     'MAD2L1',
#     'MCM10',
#     'MCM2',
#     'MCM4',
#     'MCM5',
#     'MCM6',
#     'MCM7',
#     'MELK',
#     'MIS18A',
#     'MKI67',
#     'MSH2',
#     'MT1E',
#     'MYB',
#     'MYBL1',
#     'MYBL2',
#     'NCAPG',
#     'NCAPG2',
#     'NCAPH',
#     'NDC80',
#     'NEIL3',
#     'NEK2',
#     'NFIB',
#     'NNMT',
#     'NUDT1',
#     'NUP107',
#     'NUSAP1',
#     'NXT2',
#     'OIP5',
#     'ORC6',
#     'PAICS',
#     'PARP2',
#     'PBK',
#     'PCNA',
#     'PDGFRA',
#     'PHGDH',
#     'PKMYT1',
#     'PLAC8',
#     'PLK1',
#     'PLK4',
#     'PLS3',
#     'POLA2',
#     'POLE2',
#     'POLE3',
#     'POLQ',
#     'PPIH',
#     'PRC1',
#     'PRIM1',
#     'PRPS1',
#     'PSIP1',
#     'PTTG1',
#     'RACGAP1',
#     'RAD51',
#     'RAD51AP1',
#     'RAD54B',
#     'RAD54L',
#     'RANBP1',
#     'RBBP8',
#     'RFC2',
#     'RFC3',
#     'RFC4',
#     'RFC5',
#     'RHOBTB3',
#     'RMI1',
#     'RNASEH2A',
#     'RPA2',
#     'RPA3',
#     'RRM1',
#     'RRM2',
#     'SEPT11',
#     'SHCBP1',
#     'SKA1',
#     'SKP2',
#     'SMC2',
#     'SMC3',
#     'SMC4',
#     'SNRPA1',
#     'SNRPD1',
#     'SPAG5',
#     'SPC25',
#     'SRSF3',
#     'SSRP1',
#     'STIL',
#     'STMN1',
#     'TACC3',
#     'TDP1',
#     'TIMELESS',
#     'TIPIN',
#     'TK1',
#     'TMPO',
#     'TOP2A',
#     'TPBG',
#     'TPX2',
#     'TRA2B',
#     'TRIP13',
#     'TRMT5',
#     'TROAP',
#     'TTK',
#     'TUBB',
#     'TYMS',
#     'UBE2C',
#     'UBE2S',
#     'VRK1',
#     'WDHD1',
#     'YWHAH',
#     'ZDHHC6',
#     'ZWILCH',
#     'ZWINT']},
#   'DEGcount': 363,
#   'pubchem_id': '3926765'},
#  {'pert_desc': 'TG101348',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K12502280',
#   'cell_id': 'A375',
#   'pert_dose': '11.1',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC006_A375_24H:BRD-K12502280:11.1',
#   'score': 0.0237,
#   'overlap': {'up/up': ['BTG2',
#     'CA2',
#     'CAP2',
#     'CD52',
#     'CES2',
#     'CLIC5',
#     'CPA3',
#     'DSP',
#     'EPHX1',
#     'F11R',
#     'FRY',
#     'GPR137B',
#     'GRB7',
#     'GSN',
#     'HIST2H2BE',
#     'IPO13',
#     'JAG1',
#     'KLHL24',
#     'LPAR6',
#     'MAPRE2',
#     'MTSS1',
#     'NCF2',
#     'NEBL',
#     'NOTCH1',
#     'PCK1',
#     'PDE4DIP',
#     'PEG3',
#     'PTPRC',
#     'RPS6KA2',
#     'SIK1',
#     'SLC27A6',
#     'SLC6A8',
#     'SPRY1',
#     'TM7SF2',
#     'TST'],
#    'dn/dn': ['AKR1B1',
#     'ALDH1A3',
#     'ANP32E',
#     'ANXA1',
#     'APOBEC3B',
#     'ARL6IP1',
#     'ASF1B',
#     'ASPM',
#     'AURKA',
#     'AURKB',
#     'AXL',
#     'BCLAF1',
#     'BIRC5',
#     'BORA',
#     'BRCA1',
#     'BUB1',
#     'C1ORF112',
#     'C1S',
#     'CALD1',
#     'CBR3',
#     'CCNA2',
#     'CCNB2',
#     'CCND1',
#     'CCNE2',
#     'CCNF',
#     'CDC123',
#     'CDC25A',
#     'CDC42',
#     'CDC45',
#     'CDC6',
#     'CDC7',
#     'CDCA3',
#     'CDCA8',
#     'CDK1',
#     'CDKN3',
#     'CDT1',
#     'CENPA',
#     'CENPE',
#     'CENPF',
#     'CENPM',
#     'CENPN',
#     'CEP55',
#     'CHAF1A',
#     'CHAF1B',
#     'CHEK1',
#     'CHEK2',
#     'CIT',
#     'CKAP2',
#     'CKS1B',
#     'COL1A2',
#     'COL3A1',
#     'COL6A1',
#     'COL6A3',
#     'CSE1L',
#     'CTSC',
#     'CXCL1',
#     'DBF4',
#     'DCK',
#     'DDX39A',
#     'DDX46',
#     'DEPDC1',
#     'DHFR',
#     'DKK1',
#     'DLGAP5',
#     'DNA2',
#     'DNAJC9',
#     'DNMT3B',
#     'DONSON',
#     'DSCC1',
#     'DTL',
#     'ECT2',
#     'EED',
#     'EIF4A3',
#     'ERCC6L',
#     'ESPL1',
#     'EXO1',
#     'EXOSC2',
#     'EXOSC8',
#     'EXOSC9',
#     'EZH2',
#     'FAM111A',
#     'FAM57A',
#     'FAM64A',
#     'FANCA',
#     'FANCI',
#     'FBXO5',
#     'FEN1',
#     'FOSL1',
#     'FOXM1',
#     'FSTL1',
#     'FXYD5',
#     'GINS1',
#     'GINS2',
#     'GPRC5A',
#     'GTSE1',
#     'H2AFX',
#     'HAT1',
#     'HIST1H4C',
#     'HJURP',
#     'HLTF',
#     'HMGB1',
#     'HMGB2',
#     'HMMR',
#     'HNRNPD',
#     'HOXC10',
#     'HOXC6',
#     'HSPA14',
#     'HSPA8',
#     'HSPE1',
#     'IFITM2',
#     'IFITM3',
#     'KIAA0101',
#     'KIF11',
#     'KIF14',
#     'KIF15',
#     'KIF18A',
#     'KIF18B',
#     'KIF20A',
#     'KIF20B',
#     'KIF23',
#     'KIF2C',
#     'KIF4A',
#     'KIFC1',
#     'KRT7',
#     'LIG1',
#     'LMNB1',
#     'LMNB2',
#     'LSM3',
#     'LSM6',
#     'MAD2L1',
#     'MARCKS',
#     'MCM10',
#     'MCM2',
#     'MCM4',
#     'MCM5',
#     'MCM6',
#     'MCM7',
#     'MELK',
#     'MIS18A',
#     'MKI67',
#     'MOK',
#     'MRPL3',
#     'MT1E',
#     'MT2A',
#     'MYBL2',
#     'NCAPG',
#     'NCAPG2',
#     'NCAPH',
#     'NDC80',
#     'NEIL3',
#     'NEK2',
#     'NME4',
#     'NUDT1',
#     'NUP155',
#     'NUP43',
#     'NUP62',
#     'NUSAP1',
#     'OIP5',
#     'ORC6',
#     'PAICS',
#     'PARP2',
#     'PBK',
#     'PDGFA',
#     'PI3',
#     'PKMYT1',
#     'PLAC8',
#     'PLAUR',
#     'PLK1',
#     'PLK4',
#     'POLA2',
#     'POLE2',
#     'POLQ',
#     'POLR3K',
#     'PPIG',
#     'PPIH',
#     'PRC1',
#     'PRIM1',
#     'PRPF4',
#     'PRSS23',
#     'PSMC3IP',
#     'PSMD14',
#     'PTTG1',
#     'RACGAP1',
#     'RAD51',
#     'RAD51AP1',
#     'RAD54B',
#     'RBL1',
#     'RFC2',
#     'RFC3',
#     'RFC4',
#     'RFC5',
#     'RNASEH2A',
#     'RPA2',
#     'RPA3',
#     'RPP25',
#     'RPP30',
#     'RPS11',
#     'RRM1',
#     'RRM2',
#     'S100A11',
#     'S100A2',
#     'SHCBP1',
#     'SKA1',
#     'SKP2',
#     'SLC19A1',
#     'SMC2',
#     'SMC4',
#     'SNRPA1',
#     'SNRPB',
#     'SNRPD1',
#     'SNRPE',
#     'SNRPF',
#     'SPAG5',
#     'SPARC',
#     'SPATS2L',
#     'SPC25',
#     'SRP72',
#     'SRSF3',
#     'SRSF7',
#     'STEAP3',
#     'STIL',
#     'STMN1',
#     'SYNCRIP',
#     'TACC3',
#     'TDP1',
#     'TFAP2B',
#     'TIPIN',
#     'TK1',
#     'TMEM97',
#     'TMPO',
#     'TNFAIP2',
#     'TOP2A',
#     'TPX2',
#     'TRA2B',
#     'TRIP13',
#     'TROAP',
#     'TTK',
#     'TUBB',
#     'TUBG1',
#     'TYMS',
#     'UAP1',
#     'UBE2C',
#     'UBE2S',
#     'UGCG',
#     'USP1',
#     'VRK1',
#     'ZWILCH',
#     'ZWINT']},
#   'DEGcount': 495,
#   'pubchem_id': '16722836'},
#  {'pert_desc': 'vorinostat',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K81418486',
#   'cell_id': 'HA1E',
#   'pert_dose': '11.1',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC006_HA1E_24H:BRD-K81418486:11.1',
#   'score': 0.0237,
#   'overlap': {'up/up': ['A2M',
#     'ABCA8',
#     'ABCG1',
#     'ADCY9',
#     'ADH1B',
#     'ADRB2',
#     'AGT',
#     'ALDOC',
#     'AQP1',
#     'AREG',
#     'ATP1B1',
#     'BTG2',
#     'C10ORF10',
#     'C1QA',
#     'C1QB',
#     'C3AR1',
#     'CA2',
#     'CACNA2D2',
#     'CCDC69',
#     'CD163',
#     'CDKN1C',
#     'CFD',
#     'CHGB',
#     'CHI3L2',
#     'CLEC3B',
#     'COBL',
#     'CORO1A',
#     'COX7A1',
#     'CPVL',
#     'CSF1R',
#     'CYB5R1',
#     'CYBB',
#     'ECM2',
#     'EDNRB',
#     'ENPP4',
#     'EPHX1',
#     'F11R',
#     'F13A1',
#     'FAM117A',
#     'FOXO4',
#     'GATM',
#     'GIMAP6',
#     'GLUL',
#     'GPX3',
#     'GRK5',
#     'HSPA1A',
#     'ICAM2',
#     'IPO13',
#     'ITM2A',
#     'JAG1',
#     'JUP',
#     'KLHL24',
#     'LCK',
#     'MAOB',
#     'MAPRE2',
#     'METTL7A',
#     'MTUS1',
#     'NDRG4',
#     'NEBL',
#     'OLFM1',
#     'PECAM1',
#     'PIK3R3',
#     'PLA2G15',
#     'PRKAR2B',
#     'PRKCB',
#     'PTGER4',
#     'RAP1GAP',
#     'RAPGEF5',
#     'RCAN2',
#     'REEP1',
#     'RHOB',
#     'RNASE6',
#     'ROGDI',
#     'RRAGD',
#     'S100A14',
#     'S100A8',
#     'S100A9',
#     'S100P',
#     'SCGB1A1',
#     'SEPP1',
#     'SFTPC',
#     'SNN',
#     'THBD',
#     'TKTL1',
#     'TM7SF2',
#     'TPD52',
#     'TSPAN7',
#     'TYROBP',
#     'VSIG4',
#     'ZDHHC11',
#     'ZFP36'],
#    'dn/dn': ['ABCC4',
#     'ACAT2',
#     'ACTN1',
#     'ADAM12',
#     'ALCAM',
#     'ALDH1A3',
#     'AMIGO2',
#     'ANP32B',
#     'ANXA1',
#     'ANXA5',
#     'APOBEC3B',
#     'ARF4',
#     'ATF1',
#     'ATF5',
#     'AXL',
#     'BASP1',
#     'BAZ1A',
#     'BEX1',
#     'BST2',
#     'CA12',
#     'CBR3',
#     'CCL2',
#     'CCNA2',
#     'CCND1',
#     'CD44',
#     'CD58',
#     'CD59',
#     'CDH6',
#     'CFB',
#     'CFI',
#     'CKAP4',
#     'COL1A1',
#     'COL1A2',
#     'COL5A1',
#     'COL5A2',
#     'COL6A1',
#     'COL6A2',
#     'DCTD',
#     'DEK',
#     'DLC1',
#     'DLG5',
#     'DOCK10',
#     'DRAM1',
#     'ECM1',
#     'EFEMP2',
#     'EMP3',
#     'EMX2',
#     'ENC1',
#     'EPHB2',
#     'FAM57A',
#     'FASN',
#     'FBN1',
#     'FGF2',
#     'FNDC3B',
#     'FOSL1',
#     'FOXM1',
#     'FSTL1',
#     'FZD6',
#     'FZD7',
#     'GAD1',
#     'GLIPR1',
#     'GPX1',
#     'GSTO1',
#     'HAS2',
#     'HDGF',
#     'HMGB1',
#     'HMGB2',
#     'HNRNPA1',
#     'HNRNPD',
#     'HOXA10',
#     'HOXB2',
#     'HOXB6',
#     'HOXB7',
#     'HS3ST3A1',
#     'IFI16',
#     'IFITM3',
#     'IFNGR2',
#     'IGFBP4',
#     'IL6ST',
#     'IL7R',
#     'IRAK1',
#     'ITGB5',
#     'KIF18B',
#     'KIF20A',
#     'KLK10',
#     'KPNB1',
#     'KRT18',
#     'LAMC1',
#     'LMNB1',
#     'LOX',
#     'LOXL1',
#     'LOXL2',
#     'LYPD1',
#     'MAFF',
#     'MAP4K5',
#     'MARCKS',
#     'MEIS1',
#     'MET',
#     'MICALL1',
#     'MOK',
#     'MYOF',
#     'NBN',
#     'NFKB1',
#     'NME4',
#     'NMI',
#     'NNMT',
#     'NRIP1',
#     'NSMAF',
#     'OXTR',
#     'PDGFA',
#     'PDGFC',
#     'PDLIM4',
#     'PDZK1IP1',
#     'PLAC8',
#     'PLAUR',
#     'PLK1',
#     'PLOD2',
#     'PLP2',
#     'POLE2',
#     'PRSS23',
#     'PSMB8',
#     'PTX3',
#     'RAD23B',
#     'RCN1',
#     'RIPK2',
#     'RPL14',
#     'RPL27A',
#     'RPL37A',
#     'RPL38',
#     'RPS11',
#     'S100A11',
#     'S100A2',
#     'SALL1',
#     'SCRN1',
#     'SDC2',
#     'SEMA3C',
#     'SERPINH1',
#     'SFRP1',
#     'SGCB',
#     'SHCBP1',
#     'SLC25A37',
#     'SLC35F2',
#     'SLC7A1',
#     'SLCO1B3',
#     'SMS',
#     'SNRPE',
#     'SPARC',
#     'SPOCK1',
#     'SRC',
#     'SRSF3',
#     'SRSF7',
#     'STAG1',
#     'STAG2',
#     'STC2',
#     'STMN1',
#     'TFPI2',
#     'TGFB1I1',
#     'TLK1',
#     'TNFAIP2',
#     'TNFRSF11B',
#     'TNS3',
#     'TOP2A',
#     'TP53',
#     'TPM4',
#     'TUBB',
#     'TXN',
#     'TYMS',
#     'UBE2C',
#     'UBE2E3',
#     'UFC1',
#     'UGDH',
#     'VCAN',
#     'VEGFC',
#     'WNT5B',
#     'WSB2',
#     'XBP1',
#     'YWHAE',
#     'ZBTB38',
#     'ZEB1',
#     'ZYX']},
#   'DEGcount': 502,
#   'pubchem_id': '5311',
#   'drugbank_id': 'DB02546'},
#  {'pert_desc': 'vorinostat',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K81418486',
#   'cell_id': 'HA1E',
#   'pert_dose': '10.0',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC006_HA1E_24H:BRD-K81418486:10.0',
#   'score': 0.023,
#   'overlap': {'up/up': ['A2M',
#     'ABLIM1',
#     'ADCY9',
#     'ADH1B',
#     'ADRB2',
#     'AGT',
#     'ALDOC',
#     'AQP1',
#     'ATP1B1',
#     'ATP2A3',
#     'BTG2',
#     'C10ORF10',
#     'C1QA',
#     'C1QB',
#     'CA2',
#     'CACNA2D2',
#     'CCDC69',
#     'CD93',
#     'CECR1',
#     'CFD',
#     'CHGB',
#     'CHI3L2',
#     'CLDN18',
#     'CORO1A',
#     'COX7A1',
#     'CX3CR1',
#     'CYB5R1',
#     'CYBB',
#     'CYP1A1',
#     'DGKD',
#     'EDNRB',
#     'EPHX1',
#     'F11R',
#     'FAM117A',
#     'FRY',
#     'FXYD6',
#     'GATM',
#     'GCDH',
#     'GIMAP6',
#     'GPD1L',
#     'GRK5',
#     'HSPA1A',
#     'IMPA2',
#     'IRF8',
#     'ITM2A',
#     'JAG1',
#     'JUP',
#     'KDR',
#     'KLHL24',
#     'MAOB',
#     'MAPRE2',
#     'MTUS1',
#     'NEBL',
#     'NOTCH3',
#     'OLFM1',
#     'PCDH17',
#     'PECAM1',
#     'PEG3',
#     'PFKM',
#     'PIK3R3',
#     'PLA2G15',
#     'PLA2G16',
#     'PRKACA',
#     'PRKAR2B',
#     'RAP1GAP',
#     'RAP1GAP2',
#     'RAPGEF5',
#     'REEP1',
#     'RET',
#     'RHOB',
#     'RNASE6',
#     'ROGDI',
#     'RRAGD',
#     'S100A14',
#     'S100A8',
#     'S100P',
#     'SCGB1A1',
#     'SEPP1',
#     'SFTPC',
#     'SNN',
#     'THBD',
#     'TM7SF2',
#     'TPD52',
#     'TPPP3',
#     'TSPAN7',
#     'ZDHHC11',
#     'ZFP36'],
#    'dn/dn': ['ABCC4',
#     'ACAT2',
#     'ACTN1',
#     'ADAM12',
#     'ADH5',
#     'AIM1',
#     'ALCAM',
#     'ANP32B',
#     'ANXA1',
#     'ANXA5',
#     'APOBEC3B',
#     'ATF1',
#     'ATF5',
#     'ATP6V0E1',
#     'ATXN1',
#     'AURKA',
#     'BASP1',
#     'BAZ1A',
#     'BCAT1',
#     'BEX1',
#     'BST2',
#     'C6ORF62',
#     'CA12',
#     'CBR3',
#     'CCL2',
#     'CCNA2',
#     'CCND1',
#     'CD44',
#     'CD58',
#     'CD59',
#     'CDH6',
#     'CDK2AP1',
#     'CENPA',
#     'CFI',
#     'CKAP4',
#     'CNPY2',
#     'COL1A1',
#     'COL5A1',
#     'COL5A2',
#     'COL6A1',
#     'COL6A2',
#     'COMT',
#     'CXCL12',
#     'DCTD',
#     'DEK',
#     'DERA',
#     'DIMT1',
#     'DLC1',
#     'DLG5',
#     'DOCK10',
#     'DPYSL3',
#     'DRAM1',
#     'ECM1',
#     'ECT2',
#     'EFEMP2',
#     'EGFR',
#     'EMP3',
#     'EMX2',
#     'EPHB2',
#     'FAM57A',
#     'FBN1',
#     'FERMT1',
#     'FKBP11',
#     'FNDC3B',
#     'FOSL1',
#     'FOXM1',
#     'FSTL1',
#     'FZD7',
#     'GAD1',
#     'GBP1',
#     'GGH',
#     'GLIPR1',
#     'GREM1',
#     'GRIA2',
#     'GSTO1',
#     'HAS2',
#     'HDGF',
#     'HMGB2',
#     'HNRNPH1',
#     'HOXA10',
#     'HOXB2',
#     'HOXB6',
#     'HOXB7',
#     'IFI16',
#     'IGF1',
#     'IGFBP4',
#     'IL6ST',
#     'IL7R',
#     'IRAK1',
#     'ITGB5',
#     'KIAA0101',
#     'KIF20A',
#     'KPNB1',
#     'KRT18',
#     'KRT19',
#     'LAMC1',
#     'LMNB1',
#     'LOX',
#     'LOXL1',
#     'LOXL2',
#     'LYPD1',
#     'MAFF',
#     'MAP4K5',
#     'MAPK13',
#     'MARCKS',
#     'MCM5',
#     'MEIS1',
#     'MET',
#     'MFAP5',
#     'MICALL1',
#     'MMP7',
#     'MOK',
#     'MYLK',
#     'MYOF',
#     'NBN',
#     'NFKB1',
#     'NME4',
#     'NMI',
#     'NNMT',
#     'NRIP1',
#     'NSMAF',
#     'OXTR',
#     'PBK',
#     'PDGFA',
#     'PDGFC',
#     'PDIA3',
#     'PDLIM4',
#     'PDZK1IP1',
#     'PHLDA1',
#     'PLK1',
#     'PLOD2',
#     'PLP2',
#     'POLE2',
#     'PRC1',
#     'PRKCA',
#     'PRSS23',
#     'PSMB8',
#     'PTX3',
#     'RAD23B',
#     'RCN1',
#     'RIPK2',
#     'RNH1',
#     'RPL14',
#     'RPL27A',
#     'RPL37A',
#     'RPL38',
#     'RPS11',
#     'S100A11',
#     'S100A2',
#     'SALL1',
#     'SCRN1',
#     'SDC2',
#     'SEMA3C',
#     'SERPINH1',
#     'SFRP1',
#     'SHCBP1',
#     'SLC25A37',
#     'SLC2A1',
#     'SLC2A10',
#     'SLC35F2',
#     'SLC7A1',
#     'SLCO1B3',
#     'SMAGP',
#     'SNRPE',
#     'SPOCK1',
#     'STAG1',
#     'STAG2',
#     'TGFB1I1',
#     'TGFBI',
#     'TLK1',
#     'TMED3',
#     'TNFAIP2',
#     'TNFRSF11B',
#     'TNS3',
#     'TP53',
#     'TP53I3',
#     'TPBG',
#     'TPX2',
#     'TUBB',
#     'TXN',
#     'TYMS',
#     'UBE2C',
#     'UBE2E3',
#     'UGDH',
#     'VCAN',
#     'WNT5B',
#     'WSB2',
#     'XBP1',
#     'YWHAE',
#     'ZBTB38',
#     'ZEB1',
#     'ZWINT']},
#   'DEGcount': 536,
#   'pubchem_id': '5311',
#   'drugbank_id': 'DB02546'},
#  {'pert_desc': '-666',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K68548958',
#   'cell_id': 'MCF7',
#   'pert_dose': '20.0',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC006_MCF7_24H:BRD-K68548958:20.0',
#   'score': 0.023,
#   'overlap': {'up/up': ['AREG',
#     'ATP1B1',
#     'BTG2',
#     'CCND2',
#     'DNAJB2',
#     'DSP',
#     'ERBB2',
#     'FHL2',
#     'GSN',
#     'GSTK1',
#     'HCAR3',
#     'NOTCH1',
#     'OBSL1',
#     'PIK3C2B',
#     'PTP4A3',
#     'S100A8',
#     'SESN1',
#     'SIK1',
# ...
#     'PTTG1',
#     'RACGAP1',
#     'RAD51',
#     'RAD51AP1',
#     'RAD51C',
#     'RAD54L',
#     'RFC2',
#     'RFC3',
#     'RFC4',
#     'RHOBTB3',
#     'RNASEH2A',
#     'RPS4Y1',
#     'RRM1',
#     'RRM2',
#     'SDC2',
#     'SEPT11',
#     'SFRP1',
#     'SHCBP1',
#     'SKA1',
#     'SKP2',
#     'SMC2',
#     'SMC4',
#     'SPAG5',
#     'SPC25',
#     'SRP72',
#     'STMN1',
#     'TACC3',
#     'TACSTD2',
#     'TDP1',
#     'THBS1',
#     'TIMELESS',
#     'TIMM13',
#     'TK1',
#     'TMPO',
#     'TOP2A',
#     'TPBG',
#     'TPX2',
#     'TRIP13',
#     'TROAP',
#     'TRPS1',
#     'TTK',
#     'TUBB',
#     'TYMS',
#     'UBE2C',
#     'UBE2S',
#     'USP1',
#     'VRK1',
#     'ZWILCH',
#     'ZWINT']},
#   'DEGcount': 300,
#   'pubchem_id': '6708778'},
#  {'pert_desc': '-666',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-A35588707',
#   'cell_id': 'NPC',
#   'pert_dose': '10.0',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC016_NPC_24H:BRD-A35588707:10.0',
#   'score': 0.019,
#   'overlap': {'up/up': ['CA4',
#     'CARD10',
#     'CD52',
#     'CD74',
#     'CES2',
#     'CFD',
#     'CLCA1',
#     'CXCR4',
#     'EGLN3',
#     'ELANE',
#     'G0S2',
#     'GMPR',
#     'HSPA6',
#     'HSPB3',
#     'HSPB8',
#     'JAG1',
#     'MAOA',
#     'MPO',
#     'MS4A3',
#     'PCK1',
#     'PRKCQ',
#     'RAB20',
#     'RAP1GAP2',
#     'REG1A',
#     'REG3A',
#     'S100A8',
#     'SERPINA1',
#     'WBP2',
#     'WT1',
#     'ZNF91'],
#    'dn/dn': ['ABCE1',
#     'ACOT7',
#     'AGPAT5',
#     'AKR1B1',
#     'ALCAM',
#     'ALDH1A1',
#     'ANP32E',
#     'ARL6IP1',
#     'ASCL1',
#     'AURKA',
#     'AXL',
#     'BIRC5',
#     'BST2',
#     'CALD1',
#     'CBFB',
#     'CCNA2',
#     'CCNB2',
#     'CCNF',
#     'CDC20',
#     'CDC25A',
#     'CDH11',
#     'CDKN3',
#     'CENPF',
#     'CEP170',
#     'CHEK2',
#     'CKS2',
#     'CNOT7',
#     'COL11A1',
#     'COL5A2',
#     'COTL1',
#     'CSE1L',
#     'CSRP1',
#     'CYP51A1',
#     'DDX3Y',
#     'DHCR24',
#     'DKK1',
#     'DLGAP5',
#     'DNAJC15',
#     'DTL',
#     'DUSP4',
#     'DYNLL1',
#     'EBP',
#     'EIF5A',
#     'ELOVL6',
#     'ETNK1',
#     'EZH2',
#     'FABP7',
#     'FAM64A',
#     'FBLN1',
#     'FKBP3',
#     'FN1',
#     'FSTL1',
#     'G3BP1',
#     'GAS1',
#     'GPX1',
#     'GSTA4',
#     'H2AFZ',
#     'HIST1H4C',
#     'HMGB2',
#     'HN1',
#     'HNRNPH1',
#     'IGF2BP2',
#     'IGFBP3',
#     'ISL1',
#     'ITGB5',
#     'KIF5C',
#     'KPNA2',
#     'KPNB1',
#     'KRT7',
#     'LAMA4',
#     'LAMB1',
#     'LBR',
#     'LIG1',
#     'MAP4K4',
#     'MARCKS',
#     'MELK',
#     'MFAP5',
#     'MGAT2',
#     'MMP11',
#     'MSMO1',
#     'MYH10',
#     'NAP1L1',
#     'NEFH',
#     'NEK2',
#     'NETO2',
#     'NLGN4X',
#     'NME4',
#     'NPY',
#     'NR2F1',
#     'NR2F2',
#     'NRIP1',
#     'NUP62',
#     'OAT',
#     'OPN3',
#     'PAFAH1B3',
#     'PAICS',
#     'PDLIM2',
#     'PENK',
#     'PHGDH',
#     'PLAGL1',
#     'POLE2',
#     'PPP2R2A',
#     'PSAT1',
#     'PSPH',
#     'PTGIS',
#     'PTMA',
#     'PTP4A1',
#     'PTP4A2',
#     'PTPRZ1',
#     'PTTG1',
#     'QDPR',
#     'RAB31',
#     'RAP1GDS1',
#     'RFC5',
#     'RGS4',
#     'RPS11',
#     'RPS4Y1',
#     'SCD',
#     'SEPT11',
#     'SERPINE2',
#     'SET',
#     'SFRP1',
#     'SGPL1',
#     'SLIT2',
#     'SMARCC1',
#     'SMC4',
#     'SMS',
#     'SNX6',
#     'SOX11',
#     'SPARC',
#     'SRSF6',
#     'STMN1',
#     'SULF1',
#     'SYNCRIP',
#     'SYT1',
#     'TCF12',
#     'TIMP3',
#     'TLE4',
#     'TMEM2',
#     'TMF1',
#     'TNS3',
#     'TOP2A',
#     'TUBB',
#     'TYMS',
#     'UBE2C',
#     'UBE2S',
#     'USP22',
#     'VRK1',
#     'XPO1',
#     'YKT6',
#     'YWHAQ',
#     'ZC3H13',
#     'ZWINT']},
#   'DEGcount': 291,
#   'pubchem_id': '6708778'},
#  {'pert_desc': 'vorinostat',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K81418486',
#   'cell_id': 'HCC515',
#   'pert_dose': '10.0',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC001_HCC515_24H:BRD-K81418486:10.0',
#   'score': 0.0188,
#   'overlap': {'up/up': ['ABAT',
#     'ALDOC',
#     'AREG',
#     'CDKN1C',
#     'CYB5R1',
#     'EDNRB',
#     'EFHD1',
#     'FAM117A',
#     'FGF9',
#     'FHL1',
#     'FOXO4',
#     'GCDH',
#     'GPX3',
#     'HIST2H2BE',
#     'HSPA1A',
#     'ISYNA1',
#     'MAOB',
#     'PCK1',
#     'PDLIM3',
#     'PEG3',
#     'PFKM',
#     'PLA2G15',
#     'PTGER4',
#     'RAP1GAP',
#     'RCAN2',
#     'REEP1',
#     'RHOB',
#     'S100A8',
#     'SLC25A4',
#     'SNN',
#     'SPINK2',
#     'SULT1C2',
#     'TKTL1',
#     'TNNT1',
#     'TSPAN7',
#     'ZNF91'],
#    'dn/dn': ['AKR1C2',
#     'AKR1C3',
#     'ALDH1A1',
#     'ALDH3A1',
#     'ANP32B',
#     'ANP32E',
#     'ANXA1',
#     'ASPM',
#     'ATF1',
#     'ATF5',
#     'AURKA',
#     'AURKB',
#     'AXL',
#     'BAZ1A',
#     'BCL11A',
#     'BIRC5',
#     'BRCA1',
#     'BUB1',
#     'CCL2',
#     'CCNA2',
#     'CCNB1',
#     'CCNB2',
#     'CCND1',
#     'CCNF',
#     'CDC20',
#     'CDC25A',
#     'CDC45',
#     'CDC6',
#     'CDCA3',
#     'CDCA8',
#     'CDK1',
#     'CDK2AP1',
#     'CDT1',
#     'CENPA',
#     'CENPE',
#     'CENPF',
#     'CENPN',
#     'CEP55',
#     'CFB',
#     'CFI',
#     'CIT',
#     'CKAP2',
#     'CKAP4',
#     'CKS1B',
#     'CKS2',
#     'COMT',
#     'CRIM1',
#     'CXCL1',
#     'CXCL2',
#     'CYBRD1',
#     'DBF4',
#     'DCTD',
#     'DDAH1',
#     'DDX3Y',
#     'DEK',
#     'DEPDC1',
#     'DLC1',
#     'DLGAP5',
#     'DNAJC9',
#     'DRAM1',
#     'DTL',
#     'DUT',
#     'ECT2',
#     'EIF5A',
#     'ESPL1',
#     'EXO1',
#     'FAM57A',
#     'FANCI',
#     'FBXO5',
#     'FEN1',
#     'FOSL1',
#     'FOXM1',
#     'FSTL1',
#     'GINS2',
#     'GPRC5A',
#     'GTSE1',
#     'H2AFX',
#     'HELLS',
#     'HES1',
#     'HJURP',
#     'HMGA1',
#     'HMGB1',
#     'HMGB2',
#     'HMMR',
#     'HNRNPAB',
#     'HNRNPD',
#     'HOXB2',
#     'HOXB7',
#     'IFI16',
#     'IGFBP6',
#     'IL7R',
#     'IRAK1',
#     'KIAA0101',
#     'KIF11',
#     'KIF14',
#     'KIF15',
#     'KIF18A',
#     'KIF18B',
#     'KIF20A',
#     'KIF23',
#     'KIF2C',
#     'KIF4A',
#     'KLF5',
#     'KRT15',
#     'KRT18',
#     'KRT7',
#     'LMNB1',
#     'MAD2L1',
#     'MAPK13',
#     'MCM10',
#     'MCM2',
#     'MCM5',
#     'MCM6',
#     'MCM7',
#     'MELK',
#     'MKI67',
#     'MOCOS',
#     'MYBL2',
#     'MYC',
#     'MYOF',
#     'NCAPG',
#     'NCAPH',
#     'NDC80',
#     'NEK2',
#     'NMI',
#     'NNMT',
#     'NUP62',
#     'NUSAP1',
#     'OIP5',
#     'PBK',
#     'PCNA',
#     'PDZK1IP1',
#     'PER2',
#     'PITX1',
#     'PLAC8',
#     'PLK1',
#     'PLK4',
#     'POLE2',
#     'PPP1R14B',
#     'PRC1',
#     'PRPS2',
#     'PSMB8',
#     'PTBP1',
#     'PTX3',
#     'RACGAP1',
#     'RAD51',
#     'RAD51AP1',
#     'RPS4Y1',
#     'RRM1',
#     'RRM2',
#     'S100A11',
#     'S100A2',
#     'SFTPB',
#     'SHCBP1',
#     'SLC35F2',
#     'SLC7A11',
#     'SLCO1B3',
#     'SMAGP',
#     'SMC4',
#     'SPAG5',
#     'SPC25',
#     'SPDEF',
#     'SRSF7',
#     'STIL',
#     'TACC3',
#     'TGFBI',
#     'TLE1',
#     'TLK1',
#     'TMPO',
#     'TNFAIP2',
#     'TOP2A',
#     'TP53',
#     'TPBG',
#     'TPX2',
#     'TRA2B',
#     'TRIP13',
#     'TRIP6',
#     'TROAP',
#     'TSPAN8',
#     'TTK',
#     'TYMS',
#     'USP1',
#     'ZBTB38',
#     'ZNF652',
#     'ZWINT']},
#   'DEGcount': 375,
#   'pubchem_id': '5311',
#   'drugbank_id': 'DB02546'},
#  {'pert_desc': 'SELAMECTIN',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-A58564983',
#   'cell_id': 'HCC515',
#   'pert_dose': '10.0',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC004_HCC515_24H:BRD-A58564983:10.0',
#   'score': 0.0188,
#   'overlap': {'up/up': ['AQP3',
#     'CD52',
#     'CFD',
#     'CRISP3',
#     'CYTIP',
#     'F11R',
#     'FABP4',
#     'FGR',
#     'FOXO4',
#     'LTB',
#     'MS4A1',
#     'NEBL',
#     'PIP',
#     'RPS6KA2',
#     'S100A9',
#     'S100P',
#     'SERPINA1',
#     'TSC22D3',
#     'TXNIP',
#     'TYROBP',
#     'VEGFA'],
#    'dn/dn': ['ALDH1A1',
#     'ALDH1A3',
#     'ANP32E',
#     'ARL4C',
#     'ASF1B',
#     'ASPM',
#     'ATF5',
#     'AURKA',
#     'AURKB',
#     'BARD1',
#     'BAZ1A',
#     'BIRC5',
#     'BRCA1',
#     'BST2',
#     'BUB1',
#     'CALD1',
#     'CASP2',
#     'CCL2',
#     'CCNA2',
#     'CCND1',
#     'CCNF',
#     'CDC20',
#     'CDC25A',
#     'CDC45',
#     'CDC6',
#     'CDC7',
#     'CDCA3',
#     'CDCA8',
#     'CDK1',
#     'CDK2',
#     'CDKN3',
#     'CDT1',
#     'CENPA',
#     'CENPF',
#     'CENPM',
#     'CEP55',
#     'CHAF1A',
#     'CHAF1B',
#     'COL5A2',
#     'CSE1L',
#     'DBF4',
#     'DCK',
#     'DHFR',
#     'DLGAP5',
#     'DNAJC9',
#     'DONSON',
#     'DSCC1',
#     'DTL',
#     'DUT',
#     'EFEMP1',
#     'ESPL1',
#     'EXO1',
#     'EZH2',
#     'FAM111A',
#     'FANCG',
#     'FANCI',
#     'FANCL',
#     'FEN1',
#     'FGFR3',
#     'FLRT2',
#     'FOXM1',
#     'FSTL1',
#     'GALNT6',
#     'GAS1',
#     'GINS1',
#     'GINS2',
#     'GLO1',
#     'GTSE1',
#     'H2AFX',
#     'HELLS',
#     'HES1',
#     'HJURP',
#     'HMGB1',
#     'HMMR',
#     'HNRNPAB',
#     'HOXB7',
#     'HOXC6',
#     'HPRT1',
#     'ID2',
#     'IFI16',
#     'IGFBP5',
#     'KIAA0101',
#     'KIF11',
#     'KIF14',
#     'KIF15',
#     'KIF18B',
#     'KIF20A',
#     'KIF2C',
#     'KIF4A',
#     'KNTC1',
#     'KPNA2',
#     'LIG1',
#     'LMNB1',
#     'LMO2',
#     'LUM',
#     'LYPD1',
#     'MAD2L1',
#     'MCM10',
#     'MCM2',
#     'MCM4',
#     'MCM5',
#     'MCM6',
#     'MCM7',
#     'MELK',
#     'MIS18A',
#     'MKI67',
#     'MSH2',
#     'MSH6',
#     'MXRA5',
#     'MYBL2',
#     'NASP',
#     'NCAPD3',
#     'NCAPG',
#     'NCAPG2',
#     'NCAPH',
#     'NEK2',
#     'NFIB',
#     'NPY',
#     'NR2F2',
#     'ORC6',
#     'PA2G4',
#     'PAICS',
#     'PBK',
#     'PCNA',
#     'PLK1',
#     'PLK4',
#     'POLA2',
#     'POLE2',
#     'POLQ',
#     'POSTN',
#     'PRC1',
#     'PRIM1',
#     'PRKDC',
#     'PRPS2',
#     'PRSS23',
#     'RACGAP1',
#     'RAD51',
#     'RAD51AP1',
#     'RAD54B',
#     'RAD54L',
#     'RANBP1',
#     'RFC2',
#     'RFC3',
#     'RFC4',
#     'RFC5',
#     'RGS2',
#     'RNASEH2A',
#     'RPS26',
#     'RPS4Y1',
#     'RRM1',
#     'RRM2',
#     'SHCBP1',
#     'SKP2',
#     'SLBP',
#     'SMC2',
#     'SMC4',
#     'SNRPB',
#     'SPAG5',
#     'SPARC',
#     'SPC25',
#     'SPRR1B',
#     'SRSF3',
#     'SRSF7',
#     'STIL',
#     'TACC3',
#     'TCF4',
#     'TGFBI',
#     'TIMELESS',
#     'TK1',
#     'TMEM14A',
#     'TMEM97',
#     'TMPO',
#     'TNC',
#     'TOP2A',
#     'TPX2',
#     'TRIP13',
#     'TROAP',
#     'TSPAN8',
#     'TTK',
#     'TUBB',
#     'TUBB3',
#     'TUBB6',
#     'TUBG1',
#     'TYMS',
#     'USP1',
#     'VRK1',
#     'ZWINT']},
#   'DEGcount': 340,
#   'pubchem_id': '16667695'},
#  {'pert_desc': 'EI-293',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-A18497530',
#   'cell_id': 'PC3',
#   'pert_dose': '10.0',
#   'pert_time': '24.0',
#   'pert_time_unit': 'h',
#   'sig_id': 'CPC014_PC3_24H:BRD-A18497530:10.0',
#   'score': 0.0188,
#   'overlap': {'up/up': ['A2M',
#     'ABAT',
#     'ADH1B',
#     'AHSG',
#     'ALB',
#     'ALDH5A1',
#     'ASGR2',
#     'CA4',
#     'CD52',
#     'CD74',
#     'CES1',
#     'CKB',
#     'CLC',
#     'CLCA1',
#     'CPA3',
#     'EFHD1',
#     'ERBB4',
#     'F11R',
#     'FABP1',
#     'FHL1',
#     'FLT1',
#     'FPR3',
#     'FRY',
#     'GADD45B',
#     'GLUL',
#     'GUCY1A3',
#     'HLA-DQB1',
#     'ISYNA1',
#     'ITIH2',
#     'KLF9',
#     'LPAR6',
#     'MAOA',
#     'MT1F',
#     'MT1M',
#     'NCAM1',
#     'NPTX2',
#     'ORM1',
#     'PCK1',
#     'PDLIM3',
#     'PLVAP',
#     'PON3',
#     'PPP1R3C',
#     'PRG2',
#     'RGS5',
#     'SAMSN1',
#     'SCGB1D2',
#     'SERPIND1',
#     'SPARCL1',
#     'SUSD4',
#     'TF',
#     'TMEM204',
#     'TSPAN7',
#     'TYROBP',
#     'VEGFA',
#     'VTCN1',
#     'ZFPM2',
#     'ZSCAN18'],
#    'dn/dn': ['ACTN1',
#     'AKR1B10',
#     'ALCAM',
#     'ANXA5',
#     'ARFIP2',
#     'ARMCX6',
#     'ATG3',
#     'AURKA',
#     'BASP1',
#     'BTBD3',
#     'BUB3',
#     'CA12',
#     'CALML5',
#     'CANT1',
#     'CBR3',
#     'CCNA2',
#     'CCNB2',
#     'CD164',
#     'CDC123',
#     'CDC20',
#     'CDC25A',
#     'CDC25B',
#     'CDK1',
#     'CDKN3',
#     'CEACAM5',
#     'CENPA',
#     'CGRRF1',
#     'CLCA2',
#     'CLTC',
#     'COMMD4',
#     'COPS3',
#     'CORO1C',
#     'CRCT1',
#     'CSE1L',
#     'CSTF1',
#     'CUL2',
#     'CXCL1',
#     'CXCL6',
#     'CYP1B1',
#     'DCK',
#     'DHX15',
#     'DKK1',
#     'DLG5',
#     'DLGAP5',
#     'DUSP4',
#     'ECD',
#     'EIF2S1',
#     'EIF4E',
#     'EIF5A',
#     'EZH2',
#     'F2RL1',
#     'FABP7',
#     'FOSL1',
#     'FSTL1',
#     'FUT8',
#     'GLOD4',
#     'HMGCS1',
#     'HN1',
#     'HOXB7',
#     'HOXC6',
#     'HSPA14',
#     'HSPA8',
#     'HSPH1',
#     'IGFBP6',
#     'KCNN4',
#     'KIAA0101',
#     'KIF14',
#     'KPNB1',
#     'KRT14',
#     'KRT17',
#     'KRT6B',
#     'KRT7',
#     'KRT81',
#     'LAMB3',
#     'LRRC59',
#     'MAP4K4',
#     'MARCKS',
#     'MAX',
#     'ME1',
#     'MED1',
#     'MED6',
#     'MET',
#     'MGAT2',
#     'MNAT1',
#     'MORC4',
#     'NIPA2',
#     'NKX3-1',
#     'NOLC1',
#     'NPY',
#     'NRBF2',
#     'NRIP1',
#     'NUP62',
#     'PAICS',
#     'PARP2',
#     'PBK',
#     'PCNA',
#     'PI3',
#     'PLK1',
#     'PNMA1',
#     'PPP2R2A',
#     'PRKCDBP',
#     'PRSS3',
#     'PSMA3',
#     'PSMD11',
#     'PSMD12',
#     'PTGES',
#     'RAB22A',
#     'RAE1',
#     'RBM25',
#     'RDH11',
#     'RGS2',
#     'RPL27A',
#     'RPL36AL',
#     'RPL37A',
#     'RPL38',
#     'RPS11',
#     'RRM1',
#     'S100A2',
#     'S100A7',
#     'SACS',
#     'SAR1A',
#     'SERPINB5',
#     'SERPINE2',
#     'SFN',
#     'SLC12A2',
#     'SLC16A3',
#     'SLC20A1',
#     'SLC35F2',
#     'SLC7A1',
#     'SLIRP',
#     'SMAD3',
#     'SNAPC1',
#     'SNRPB2',
#     'SNW1',
#     'SOAT1',
#     'SOX9',
#     'SPRR1A',
#     'SPRR1B',
#     'SRP54',
#     'SRPX',
#     'STK17A',
#     'SUB1',
#     'SYNCRIP',
#     'TACC3',
#     'TBP',
#     'TFAM',
#     'TFG',
#     'TIPIN',
#     'TMEM11',
#     'TMEM97',
#     'TNFRSF10B',
#     'TNPO1',
#     'TOP1',
#     'TRIM16',
#     'TSPAN8',
#     'TXLNA',
#     'TXNRD1',
#     'TYMS',
#     'UAP1',
#     'UBE2C',
#     'USP22',
#     'UTP3',
#     'VAPA',
#     'VPS26A',
#     'VRK1',
#     'WDR43',
#     'YWHAE']},
#   'DEGcount': 405,
#   'pubchem_id': '1830'},
#  {'pert_desc': 'PD-184352',
#   'pert_dose_unit': 'um',
#   'pert_id': 'BRD-K05104363',
#   'cell_id': 'MCF10A',
#   'pert_dose': 3.33,
#   'pert_time_unit': 'h',
#   'sig_id': 'LJP005_MCF10A_24H:BRD-K05104363:3.33',
#   'pert_time': 24,
#   'score': 0.0188,
#   'overlap': {'up/up': ['ADCY9',
#     'ADRB2',
#     'CBLB',
#     'CDKN1C',
#     'CELF2',
#     'CFD',
#     'CTSD',
#     'CYB5R1',
#     'CYP4B1',
#     'DNAJB2',
#     'EFNA1',
#     'F13A1',
#     'FAM63A',
#     'FXYD3',
#     'GLUL',
#     'GSN',
#     'HBB',
#     'HCAR3',
#     'HPGD',
#     'HSPB8',
#     'KRT4',
#     'KRT8',
#     'MSRB2',
#     'MYL9',
#     'MYO5C',
#     'NCF2',
#     'NEBL',
#     'NOL3',
#     'PDLIM1',
#     'PIK3C2B',
#     'PNRC1',
#     'PRR15L',
#     'RABGAP1L',
#     'RARRES1',
#     'S100A8',
#     'S100A9',
#     'SCGB1A1',
#     'SLC6A8',
#     'SLPI',
#     'SYNE2',
#     'TM7SF2',
#     'TNNC1',
#     'TPM1',
#     'TSC22D3',
#     'TTC39A',
#     'VAMP8'],
#    'dn/dn': ['ANP32E',
#     'APOBEC3B',
#     'ASF1B',
#     'ASPM',
#     'AURKA',
#     'AURKB',
#     'BIRC5',
#     'BRCA1',
#     'BUB1',
#     'BZW1',
#     'CCNA2',
#     'CCNB2',
#     'CCND1',
#     'CCNE2',
#     'CCNF',
#     'CDC20',
#     'CDC25A',
#     'CDC45',
#     'CDC6',
#     'CDCA3',
#     'CDK1',
#     'CDKN3',
#     'CENPA',
#     'CENPE',
#     'CENPN',
#     'CEP55',
#     'CHEK2',
#     'CKS1B',
#     'CKS2',
#     'CSE1L',
#     'CYR61',
#     'DBF4',
#     'DCK',
#     'DDX39A',
#     'DEPDC1',
#     'DHFR',
#     'DKK1',
#     'DLGAP5',
#     'DNAJC9',
#     'DONSON',
#     'DSCC1',
#     'DTL',
#     'DUSP4',
#     'DUSP6',
#     'ECT2',
#     'EGR1',
#     'EIF4EBP1',
#     'ENC1',
#     'ESPL1',
#     'ETV4',
#     'ETV5',
#     'EXO1',
#     'EXOSC9',
#     'EZH2',
#     'FANCG',
#     'FANCI',
#     'FBXO5',
#     'FEN1',
#     'FKBP11',
#     'FOSL1',
#     'FOXM1',
#     'GAL',
#     'GALNT6',
#     'GGH',
#     'GINS1',
#     'GINS2',
#     'GTSE1',
#     'H2AFZ',
#     'HELLS',
#     'HIST1H4C',
#     'HJURP',
#     'HMGA1',
#     'HMGA2',
#     'HMGB2',
#     'IER3',
#     'IL13RA2',
#     'KIAA0101',
#     'KIF11',
#     'KIF14',
#     'KIF15',
#     'KIF18B',
#     'KIF20A',
#     'KIF23',
#     'KIF4A',
#     'LBR',
#     'LIG1',
#     'LMNB1',
#     'LSM6',
#     'MAD2L1',
#     'MAFF',
#     'MAGEB2',
#     'MCM10',
#     'MCM2',
#     'MCM4',
#     'MCM5',
#     'MCM6',
#     'MCM7',
#     'MELK',
#     'MIS18A',
#     'MKI67',
#     'MSH6',
#     'MYBL1',
#     'MYBL2',
#     'NAV3',
#     'NCAPG',
#     'NCAPG2',
#     'NCAPH',
#     'NDC80',
#     'NEIL3',
#     'NEK2',
#     'NETO2',
#     'NPM3',
#     'NT5E',
#     'NUSAP1',
#     'ODC1',
#     'ORC6',
#     'PARP2',
#     'PBK',
#     'PCNA',
#     'PCSK1',
#     'PHGDH',
#     'PHLDA1',
#     'PHLDA2',
#     'PLAT',
#     'PLK1',
#     'PRC1',
#     'PRIM1',
#     'PSMC3IP',
#     'PSRC1',
#     'RACGAP1',
#     'RAD51AP1',
#     'RANBP1',
#     'RFC2',
#     'RFC3',
#     'RFC4',
#     'RFC5',
#     'RNASEH2A',
#     'RPA2',
#     'RRM1',
#     'RRM2',
#     'SACS',
#     'SERPINE2',
#     'SFRP1',
#     'SH2B3',
#     'SHCBP1',
#     'SLC20A1',
#     'SMC4',
#     'SNRPB',
#     'SPC25',
#     'SRSF7',
#     'STEAP1',
#     'STMN1',
#     'STX1A',
#     'TACC3',
#     'TFAM',
#     'TIPIN',
#     'TMEM158',
#     'TMEM97',
#     'TMPO',
#     'TNC',
#     'TOP2A',
#     'TPX2',
#     'TRIP13',
#     'TTK',
#     'TYMS',
#     'UAP1',
#     'UBE2C',
#     'UBE2S',
#     'USP1',
#     'VRK1',
#     'YKT6',
#     'ZWILCH',
#     'ZWINT']},
#   'DEGcount': 355,
#   'pubchem_id': '6918454'}]

# %%
try:
    for i in resGeneSet["topMeta"]:
        if "pert_desc" in i:
            print(i["pert_id"])
except KeyError:
    print("No such a Key")
# Out:
# BRD-K03618428
# BRD-K56343971
# BRD-K03618428
# BRD-K34581968
# BRD-K34581968
# BRD-K41895714
# BRD-K41895714
# BRD-K57080016
# BRD-K98490050
# BRD-K12502280
# BRD-K81418486
# BRD-K81418486
# BRD-K68548958
# BRD-A19037878
# BRD-A12230535
# BRD-K57080016
# BRD-K13049116
# BRD-K53414658
# BRD-A36630025
# BRD-K12502280
# BRD-K81418486
# BRD-K12343256
# BRD-A45889380
# BRD-A13122391
# BRD-K64800655
# BRD-K56343971
# BRD-K88510285
# BRD-K69932463
# BRD-K57080016
# BRD-K03618428
# BRD-K21680192
# BRD-A19037878
# BRD-K49371609
# BRD-A19037878
# BRD-K33272502
# BRD-A45889380
# BRD-K50168500
# BRD-A19037878
# BRD-K19295594
# BRD-K07762753
# BRD-A19037878
# BRD-K81418486
# BRD-K34581968
# BRD-K49865102
# BRD-A35588707
# BRD-A35588707
# BRD-K81418486
# BRD-A58564983
# BRD-A18497530
# BRD-K05104363

# %%
try:
    for i in resGeneSet["topMeta"]:
        if "pert_desc" in i:
            print(i["pubchem_id"])
except KeyError:
    print("No such a Key")
# Out:
# 24905203
# 42611257
# 24905203
# 11353973
# 11353973
# 10377751
# 10377751
# 10127622
# 3926765
# 16722836
# 5311
# 5311
# 1285940
# 6376322
# 216345
# 10127622
# 24785538
# 9911830
# 4014291
# 16722836
# 5311
# 11707110
# 23581813
# 16220015
# 46191454
# 42611257
# 387447
# 25262965
# 10127622
# 24905203
# 5458171
# 6376322
# 10275789
# 6376322
# 11296282
# 23581813
# 156414
# 6376322
# 227456
# 6604931
# 6376322
# 5311
# 11353973
# 9826528
# 6708778
# 6708778
# 5311
# 16667695
# 1830
# 6918454

# %%
try:
    for i in resGeneSet["combinations"]:
        print(i)
except KeyError:
    print("No such a Key")
# Out:
# {'X1': 'CPC006_HT29_24H:BRD-K03618428:22.2', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'value': 0.0524}
# {'X1': 'CPC006_HT29_24H:BRD-K03618428:22.2', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:10.0', 'value': 0.0516}
# {'X1': 'CPC006_HT29_24H:BRD-K03618428:22.2', 'X2': 'CPC006_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0512}
# {'X1': 'CPC006_HT29_24H:BRD-K03618428:22.2', 'X2': 'CPC007_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0486}
# {'X1': 'CPC006_HT29_24H:BRD-K03618428:22.2', 'X2': 'CPC002_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0485}
# {'X1': 'CPC006_HT29_24H:BRD-K03618428:22.2', 'X2': 'CPC006_HA1E_24H:BRD-K88510285:0.04', 'value': 0.0476}
# {'X1': 'CPC006_HT29_24H:BRD-K03618428:22.2', 'X2': 'CPC006_A375_24H:BRD-A13122391:0.08', 'value': 0.0475}
# {'X1': 'CPC006_A375_24H:BRD-K56343971:10.0', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'value': 0.0472}
# {'X1': 'CPC006_HT29_24H:BRD-K34581968:11.1', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'value': 0.0472}
# {'X1': 'CPC006_A375_24H:BRD-K56343971:10.0', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:10.0', 'value': 0.0464}
# {'X1': 'CPC006_HT29_24H:BRD-K03618428:22.2', 'X2': 'CPC006_HA1E_24H:BRD-K49371609:0.09', 'value': 0.0463}
# {'X1': 'CPC006_HT29_24H:BRD-K41895714:10.0', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'value': 0.046}
# {'X1': 'CPC006_HT29_24H:BRD-K34581968:11.1', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:10.0', 'value': 0.046}
# {'X1': 'CPC006_A375_24H:BRD-K03618428:22.2', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'value': 0.0458}
# {'X1': 'CPC006_A375_24H:BRD-K34581968:11.1', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'value': 0.0458}
# {'X1': 'CPC006_HT29_24H:BRD-K34581968:11.1', 'X2': 'CPC006_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0456}
# {'X1': 'CPC006_HT29_24H:BRD-K03618428:22.2', 'X2': 'CPC016_NPC_24H:BRD-A35588707:10.0', 'value': 0.0456}
# {'X1': 'CPC006_HT29_24H:BRD-K03618428:22.2', 'X2': 'CPC014_PC3_24H:BRD-A18497530:10.0', 'value': 0.0456}
# {'X1': 'CPC006_A375_24H:BRD-K34581968:11.1', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:10.0', 'value': 0.0454}
# {'X1': 'CPC015_MCF7_24H:BRD-K98490050:10.0', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'value': 0.0448}
# {'X1': 'CPC006_A375_24H:BRD-K03618428:22.2', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:10.0', 'value': 0.0448}
# {'X1': 'CPC006_HT29_24H:BRD-K41895714:10.0', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:10.0', 'value': 0.0448}
# {'X1': 'CPC006_A375_24H:BRD-K56343971:10.0', 'X2': 'CPC006_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0447}
# {'X1': 'CPC006_A375_24H:BRD-K41895714:10.0', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'value': 0.0446}
# {'X1': 'CPC006_A375_24H:BRD-K57080016:80.0', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'value': 0.0446}
# {'X1': 'CPC006_A375_24H:BRD-K41895714:10.0', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:10.0', 'value': 0.0446}
# {'X1': 'CPC006_HT29_24H:BRD-K41895714:10.0', 'X2': 'CPC006_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0446}
# {'X1': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'X2': 'CPC006_MCF7_24H:BRD-K68548958:20.0', 'value': 0.0443}
# {'X1': 'CPC006_A375_24H:BRD-K03618428:22.2', 'X2': 'CPC006_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0443}
# {'X1': 'CPC006_A375_24H:BRD-K34581968:11.1', 'X2': 'CPC006_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0443}
# {'X1': 'CPC006_A375_24H:BRD-K57080016:80.0', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:10.0', 'value': 0.0438}
# {'X1': 'CPC015_MCF7_24H:BRD-K98490050:10.0', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:10.0', 'value': 0.0435}
# {'X1': 'CPC006_A375_24H:BRD-K41895714:10.0', 'X2': 'CPC006_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0434}
# {'X1': 'CPC015_MCF7_24H:BRD-K98490050:10.0', 'X2': 'CPC006_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0433}
# {'X1': 'CPC006_MCF7_24H:BRD-K68548958:20.0', 'X2': 'CPC006_HA1E_24H:BRD-A19037878:10.0', 'value': 0.043}
# {'X1': 'CPC006_HA1E_24H:BRD-K81418486:10.0', 'X2': 'CPC006_MCF7_24H:BRD-K68548958:20.0', 'value': 0.0429}
# {'X1': 'CPC006_A375_24H:BRD-K57080016:80.0', 'X2': 'CPC006_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0429}
# {'X1': 'CPC006_HT29_24H:BRD-K34581968:11.1', 'X2': 'CPC007_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0429}
# {'X1': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'X2': 'CPC006_HCC515_24H:BRD-K57080016:80.0', 'value': 0.0426}
# {'X1': 'CPC006_A375_24H:BRD-K56343971:10.0', 'X2': 'CPC002_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0426}
# {'X1': 'CPC006_A375_24H:BRD-K56343971:10.0', 'X2': 'CPC007_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0426}
# {'X1': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'X2': 'CPC006_A375_24H:BRD-A12230535:44.4', 'value': 0.0425}
# {'X1': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'X2': 'CPC006_MCF7_24H:BRD-A36630025:0.35', 'value': 0.0425}
# {'X1': 'CPC006_A375_24H:BRD-K56343971:10.0', 'X2': 'CPC006_HA1E_24H:BRD-K88510285:0.04', 'value': 0.0424}
# {'X1': 'CPC006_HT29_24H:BRD-K34581968:11.1', 'X2': 'CPC002_HA1E_24H:BRD-A19037878:10.0', 'value': 0.0424}
# {'X1': 'CPC006_A375_24H:BRD-K12502280:11.1', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'value': 0.0422}
# {'X1': 'CPC006_A375_24H:BRD-K12502280:11.1', 'X2': 'CPC006_HA1E_24H:BRD-K81418486:10.0', 'value': 0.0421}
# {'X1': 'CPC006_HA1E_24H:BRD-A19037878:10.0', 'X2': 'CPC006_HCC515_24H:BRD-K57080016:80.0', 'value': 0.0421}
# {'X1': 'CPC006_A375_24H:BRD-K56343971:10.0', 'X2': 'CPC006_A375_24H:BRD-A13122391:0.08', 'value': 0.0421}
# {'X1': 'CPC006_HA1E_24H:BRD-K81418486:11.1', 'X2': 'CPC006_A375_24H:BRD-K13049116:10.0', 'value': 0.042}
